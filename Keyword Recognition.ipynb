# %%
# # Correcting the initial generated file


# def process_file(input_filename, output_filename):
#     with open(input_filename, 'r', encoding='utf-8') as file:
#         lines = file.readlines()

#     with open(output_filename, 'w', encoding='utf-8') as file:
#         for line in lines:
#             if line.strip() == '"':
#                 file.write("\n")  # write a newline for lines that are just a quote
#             elif line.strip() == '",O':
#                 continue
#             else:
#                 corrected_line = line.replace(',', '\t')
#                 file.write(corrected_line)

# process_file('data/ner/tokens_IOB.csv', 'data/ner/tokens_IOB_correct.csv')

# %%
import random

def read_and_split_data(input_filename, train_ratio=0.8, dev_ratio=0.1, test_ratio=0.1):
    # Ensure the ratios sum to 1
    assert train_ratio + dev_ratio + test_ratio == 1
    
    # Read and process the file
    with open(input_filename, 'r', encoding='utf-8') as file:
        content = file.read()
    
    # Split content into sentences based on newlines
    sentences = content.strip().split('\n\n')

    # Shuffle the sentences randomly for a fair split
    random.shuffle(sentences)

    # Calculate split indices
    total = len(sentences)
    train_end = int(total * train_ratio)
    dev_end = train_end + int(total * dev_ratio)
    
    # Create splits
    train_sentences = sentences[:train_end]
    dev_sentences = sentences[train_end:dev_end]
    test_sentences = sentences[dev_end:]

    # Save each split to a different file
    with open('data/final/splits/train.csv', 'w', encoding='utf-8') as file:
        file.write('\n\n'.join(train_sentences))
    with open('data/final/splits/dev.csv', 'w', encoding='utf-8') as file:
        file.write('\n\n'.join(dev_sentences))
    with open('data/final/splits/test.csv', 'w', encoding='utf-8') as file:
        file.write('\n\n'.join(test_sentences))

read_and_split_data('data/final/data.tsv')

# %%
def load_data(filename):
    with open(filename, 'r', encoding='utf-8') as file:
        data = file.read().strip().split('\n\n')  # Splitting data by double newlines

    formatted_data = []
    for record in data:
        text, entities = '', []
        lines = record.split('\n')
        start = 0  # Initialize start of the first token
        entity_start = None  # Initialize the start of an entity
        entity_type = None  # Initialize the entity type
        for line in lines:
            parts = line.split('\t')
            if len(parts) >= 2:  # Ensure there's at least a token and a tag
                token, tag = parts[0], parts[1]
                # Update text with token followed by space
                text += token + ' '
                end = start + len(token)  # End index of the current token
                if tag.startswith('B-') or tag.startswith('I-'):  # Check if the tag indicates an entity
                    if tag.startswith('B-'):
                        # If there was a previous entity, append it
                        if entity_start is not None:
                            entities.append((entity_start, prev_end, entity_type))
                        # Start new entity
                        entity_start = start
                        entity_type = tag.split('-')[1]
                    if tag.startswith('I-') and entity_start is not None:
                        # Continue the entity
                        entity_type = tag.split('-')[1]  # Update the type if needed (typically not necessary)
                else:
                    # If ending part of entity, append it
                    if entity_start is not None:
                        entities.append((entity_start, end, entity_type))
                        entity_start = None  # Reset for the next entity

                # Prepare for next token
                start = end + 1
                prev_end = end  # Remember the end of the last token

        # Check for any trailing entity at the end
        if entity_start is not None:
            entities.append((entity_start, prev_end, entity_type))

        # Append the parsed data if there are entities
        if entities:
            formatted_data.append((text.strip(), {'entities': entities}))

    return formatted_data

# Load the data
train_data = load_data('data/final/splits/train.csv')
dev_data = load_data('data/final/splits/dev.csv')
test_data = load_data('data/final/splits/test.csv')

# %%
train_data
# Out:
# [('Графіті № 586 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Висота від сучасної підлоги 54 см , відстань від лівого кута 51 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Графіті № 503 ( табл . LХІІ , 3 ) Публікації .',
#   {'entities': [(0, 9, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 501 ( табл .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Висота від сучасної підлоги 55 см , відстань від лівого кута 64 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('На фресці прокреслений чотириконечний хрест , основа щогли якого спи- рається на відкриту донизу одноступінчасту Голгофу .',
#   {'entities': [(10, 22, 'execution_technique'),
#     (23, 45, 'decoration'),
#     (46, 64, 'object_type')]}),
#  ('Опис .', {'entities': [(0, 6, 'inscription')]}),
#  ('Графіті № 543 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('На фресці прокреслена монограма ПІ та , на деякій відстані , літери АМѢ схематичний малюнок коня .',
#   {'entities': [(22, 34, 'epigraphic_shorthand')]}),
#  ('Молитовний напис . Графіті № 4339 ( табл .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Молитовний напис . Графіті № 529 ( табл . LХХІV ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Графіті № 500 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Графіті № 4262 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 120 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ("На фрагменті фрескового тиньку простежуються літери ПО , які найімо- вірніше розглядати як частину дієслова - прохання по[мози ] ' поможи ' . Датування .",
#   {'entities': [(99, 126, 'other'), (142, 153, 'dating_criteria')]}),
#  ('Загалом же збереженість напису добра , його складові чітко читаються : ст͠\ue01f:м҃-мнⷱ\ue003къмол\ue01fт - б͠азаме | негрѣшънаго\ue01fоана',
#   {'entities': [(11, 36, 'preservation_state')]}),
#  ('Молитовний напис . Графіті № 587 ( табл . ХLI , 4 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (52, 66, 'other')]}),
#  ('Молитовний напис . Графіті № 510 ( табл . LХV , 2 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (52, 66, 'other')]}),
#  ('ХСІІІ , 1 ) Розташування .', {'entities': [(12, 26, 'other')]}),
#  ('Графіті № 434 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ("Це означає , що на час виконання графіті дипінті , яке називало ім'я святого , вже не простежувалось .",
#   {'entities': [(33, 50, 'inscription_type')]}),
#  ('На фресці прокреслений чотириконечний хрест з розширеними у вигляді трикутників кінцями . Датування .',
#   {'entities': [(10, 22, 'execution_technique'),
#     (23, 45, 'decoration'),
#     (90, 101, 'dating_criteria')]}),
#  ('На фресці прокреслений простий чотириконечний хрест . Датування .',
#   {'entities': [(10, 30, 'execution_technique'),
#     (31, 53, 'decoration'),
#     (54, 65, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 77 см , відстань від правого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Висота від основи 203 см . Опис .',
#   {'entities': [(27, 33, 'inscription')]}),
#  ('Однак ретельне дослідження про- різів цього " орла " дозволило встановити , що спершу тут було виконане зображення ангела , яке потім через зашпакльовані вибої отримало " дзьоб " . Датування .',
#   {'entities': [(181, 192, 'dating_criteria')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  (', текст коригували В. Німчук136 та А. Залізняк137 ; В. Корнієнко138 . Розташування .',
#   {'entities': [(70, 84, 'other')]}),
#  ("Нижні рядки напису практично повністю знищені вибоями , залишився тільки верхній рядок , в якому читається дієслово - прохання помѧни ' пом'яни ' .",
#   {'entities': [(107, 133, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Графіті на фресці з зображенням св . Григорія Богослова та св . Йоанна Золотоустого Фреска розташована на північній стороні апсиди хрещальні .',
#   {'entities': [(0, 10, 'inscription'), (84, 102, 'object_type')]}),
#  ('Висота від верхньої лави синтрону 167 см , відстань від лівого ребра 153 см . Опис .',
#   {'entities': [(78, 84, 'inscription')]}),
#  ('Графіті № 4309 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Молитовний напис . Графіті № 4313 ( табл .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Господи , поможи рабу і свята Софіє , дай спасіння Власію . Датування .',
#   {'entities': [(60, 71, 'dating_criteria')]}),
#  ("Пам'ятний напис . Графіті № 608 ( табл . ХХV , 2 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (51, 65, 'other')]}),
#  ('Висота від рівня давньої підлоги 138 см , відстань від лівого кута стіни 5 см . Опис .',
#   {'entities': [(80, 86, 'inscription')]}),
#  ('На фресці прокреслені літери NW . Датування .',
#   {'entities': [(34, 45, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 506 ( табл . LХІІІ , 3 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Висота від сучасної підлоги 46 см , відстань від правого кута 19 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 84 см , відстань від лівого кута 497 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('На фресці прокреслений простий чотириконечний хрест . Датування .',
#   {'entities': [(10, 30, 'execution_technique'),
#     (31, 53, 'decoration'),
#     (54, 65, 'dating_criteria')]}),
#  ("На фресці прокреслений літери ПОМ , що найвірогідніше реконструювати тут скорочену форму дієслова - прохання пом(ози ) ' поможи ' . Датування .",
#   {'entities': [(10, 29, 'execution_technique'),
#     (89, 116, 'other'),
#     (132, 143, 'dating_criteria')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Висота від рівня сучасної підлоги 152,5 см , відстань від лівого кута стіни 382 см . Опис .',
#   {'entities': [(85, 91, 'inscription')]}),
#  ('Четвертые чтения памяти Анны Мачинской , Старая Ладога , 21–23 декабря Датування .',
#   {'entities': [(71, 82, 'dating_criteria')]}),
#  ("Пам'ятний напис .", {'entities': [(10, 17, 'inscription')]}),
#  ('Висота від сучасної підлоги 41 см , відстань від правого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 135 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Висота від сучасної підлоги 61,5 см , відстань від лівого кута 64 см . Опис .',
#   {'entities': [(71, 77, 'inscription')]}),
#  ('Авраам многогрішний . Датування .',
#   {'entities': [(22, 33, 'dating_criteria')]}),
#  ("Пам'ятний напис . Графіті № 699 ( табл . LХХХV , 1 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (53, 67, 'other')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 85 см , відстань від лівого кута 4 см . Опис .',
#   {'entities': [(68, 74, 'inscription')]}),
#  ("Вплив цієї традиції на київську ( софійську ) писемну школу слід пов'язувати з перебуванням свити митрополита Кипріана31 , який з березня 1396 р . близько півтора року знаходився у Києві32 . Датування .",
#   {'entities': [(191, 202, 'dating_criteria')]}),
#  ('Малюнок пошкоджений вибоями , проте можна встановити , що тут по- двійними замкненими рисками був прокреслений чотириконечний хрест . Датування .',
#   {'entities': [(98, 110, 'execution_technique'),
#     (111, 133, 'decoration'),
#     (134, 145, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 66,5 см , відстань від лівого кута 9 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('На фресці прокреслений простий чотириконечний хрест . Датування .',
#   {'entities': [(10, 30, 'execution_technique'),
#     (31, 53, 'decoration'),
#     (54, 65, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 42 ( табл . LVІ , 2 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Датування . 1625 р . ; за прямим датуванням .',
#   {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Графіті № 714 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 81,5 см , відстань від лівого кута 72 см . Опис .',
#   {'entities': [(71, 77, 'inscription')]}),
#  ('Висота від сучасної підлоги 97 см , відстань від лівого кута 340 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Висота від сучасної підлоги 100 см , відстань від лівого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Фресковий тиньк в місці розташування напису пошкоджений численними вибоями , тож більша частина його складових не збереглась : ---ꙗ---- | сем-----',
#   {'entities': [(10, 17, 'material')]}),
#  ('Висота від сучасної підлоги 48 см , відстань від лівого кута 67 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ("Пам'ятний напис . Графіті № 4352 ( табл . СХV , 1 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (52, 66, 'other')]}),
#  ('Висота від сучасної підлоги 183 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ("Тобто , тут знаходиться незавершена тради- ційна молитовна формула Г(оспод)и по{мози } ' Господи , поможи ' . Датування .",
#   {'entities': [(49, 76, 'other'), (110, 121, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 70,5 см , відстань від лівого кута Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Графіті № 439 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Висота від сучасної підлоги 125 см , відстань від лівого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Молитовний напис . Графіті № 531 ( табл . LХІХ , 2 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Висота від сучасної підлоги 121 см , відстань від лівого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Це свідчить про те , що на момент виконання тексту давній фресковий тиньк відвалився .',
#   {'entities': [(58, 84, 'material')]}),
#  ('Графіті № 4360 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ("Однак сучасні дослідження графіті не підтвердили версії про їх спільний зв'язок , тож вірогідніше , що невідомий автор зобразив на фресці хрест на престолі , який він міг бачити у вівтарі Софійського собору , або навіть у тій же хрещальні . Датування .",
#   {'entities': [(26, 36, 'inscription'),
#     (138, 146, 'decoration'),
#     (241, 252, 'dating_criteria')]}),
#  ('Висота від основи 81 см . Опис .', {'entities': [(26, 32, 'inscription')]}),
#  ('Графіті № 664 ( табл . LХХVІІІ , 2 ) Розташування .',
#   {'entities': [(0, 9, 'inscription'), (37, 51, 'other')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Графіті № 487 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Знаходиться на північній стіні між двома її середніми висту- пами у невеликому зондажі давнього мурування ( табл . І ) .',
#   {'entities': [(96, 107, 'object_type')]}),
#  ("Пам'ятний напис . Графіті № 4247 ( табл . VІІІ , 3 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (53, 67, 'other')]}),
#  ('Висота від сучасної підлоги 143 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Обабіч кінців перекладини проскреслені літери І\ue002С Х\ue002С. Датування .',
#   {'entities': [(55, 66, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 108,5 см , відстань від лівого кута Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ('За нею тиньк пошкоджений , тож тут , найвірогідніше , могли знаходитись й інші літери .',
#   {'entities': [(7, 24, 'material')]}),
#  ('Висота від сучасної підлоги 63 см , відстань від лівого кута 15 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Висота від сучасної підлоги 81 см , відстань від лівого кута 352 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Опис На фресці прокреслений малюнок голуба . Датування .',
#   {'entities': [(0, 7, 'inscription'),
#     (15, 42, 'decoration'),
#     (45, 56, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 105,5 см , відстань від лівого кута Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('На фресці прокреслений чотириконечний хрест .',
#   {'entities': [(10, 22, 'execution_technique'), (23, 45, 'decoration')]}),
#  ("Графіті виявлені саме на цій , відновленій у ХІІ ст. ділянці стіни , їх тридцять дев'ять , вони отримали номери 481–482 , 498–501 , 543–575 ( табл . XVIII , 9 ) .",
#   {'entities': [(0, 16, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ("Тому вважаю за доцільне все ж включити цей напис у загальний корпус софійських епіграфічних пам'яток під № 4271 .",
#   {'entities': [(43, 50, 'inscription')]}),
#  ('Напис повністю знищений молитвою Стефана ( № 4339 ) , збереглись тільки незначні фрагменти літер . Датування .',
#   {'entities': [(99, 110, 'dating_criteria')]}),
#  ("Проте форма прорізів та особливості їх виконання ідентичні , тож на фресці автор виконав молитву : Помени Г(оспо)ди мꙗ. Пом'яни , Господи , мене . Датування .",
#   {'entities': [(147, 158, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 84 см , відстань від лівого кута 335 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 141 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Висота від сучасної підлоги 107 см , відстань від лівого кута 65 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Висота від сучасної підлоги 45,5 см , відстань від лівого кута 8 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Висота від сучасної підлоги 78 см , відстань від лівого кута 64 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Давній тиньк має значні втрати , розділяючи композицію на три нерівні частини , між якими помітне мурування .',
#   {'entities': [(7, 16, 'material'), (98, 109, 'object_type')]}),
#  ("Незважаючи на пошкодження тиньку , на фресці чітко простежується ви- конаний у чотири рядки підпис до фрескового образу – о аг\ue01fос Ан\ue027\ue01fмос ' святий Анфім ' . Датування .",
#   {'entities': [(157, 168, 'dating_criteria')]}),
#  ('Графіті на фресці з зображенням орнаменту Фреска розташована на південній стороні південного виступу апсиди хре- щальні .',
#   {'entities': [(0, 10, 'inscription'), (42, 60, 'object_type')]}),
#  ('Висота від сучасної підлоги 129 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Графіті № 436 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Фрагмент напису . Графіті № 4343 ( табл .',
#   {'entities': [(18, 27, 'inscription')]}),
#  ('ХСV , 1 ) Розташування .', {'entities': [(10, 24, 'other')]}),
#  ("Пам'ятний напис . Графіті № 502 ( табл . LХІІ , 2 ) Публікації .",
#   {'entities': [(10, 17, 'inscription'), (18, 27, 'inscription')]}),
#  ('Графіті на мармуровій колоні у південній частину нартексу Мармурова колона довжиною близько 2,5 м , що нині експонується в північній частині нартексу ( табл . ХІ , 2 ) , частково пошкоджена , вона має більший діаметр та меншу висоту .',
#   {'entities': [(0, 10, 'inscription'), (58, 83, 'object_type')]}),
#  ('Молитовний напис . Графіті № 4306 ( табл .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('ХС , 4 ) Розташування .', {'entities': [(9, 23, 'other')]}),
#  ('Висота від сучасної підлоги 83 см , відстань від правого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('На поверхні мармурової колони прокреслений простий чотириконечний хрест . Датування .',
#   {'entities': [(30, 50, 'execution_technique'),
#     (51, 73, 'decoration'),
#     (74, 85, 'dating_criteria')]}),
#  ('ХLI , 2 ) Розташування .', {'entities': [(10, 24, 'other')]}),
#  ('Висота від сучасної підлоги 67 см , відстань від лівого кута 66 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ("Пам'ятний напис . Графіті № 4334 ( табл .",
#   {'entities': [(10, 17, 'inscription'), (18, 27, 'inscription')]}),
#  ('Графіті № 4246 ( табл . VІІІ , 2 ) Розташування .',
#   {'entities': [(0, 9, 'inscription'), (35, 49, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('СХIХ , 2 ) Розташування .', {'entities': [(11, 25, 'other')]}),
#  ('Висота від сучасної підлоги 45 см , відстань від лівого кута 11 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Висота від сучасної підлоги 56,5 см , відстань від лівого кута 36 см . Опис .',
#   {'entities': [(71, 77, 'inscription')]}),
#  ('СХVІ , 3 ) Розташування .', {'entities': [(11, 25, 'other')]}),
#  ("Можливо , напис пов'язаний з іменами Євдокиї та Панкрата ( № 601 ) , що розташований вище .",
#   {'entities': [(10, 26, 'inscription')]}),
#  ('Висота від сучасної підлоги 49 см , відстань від правого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Висота від сучасної підлоги 131 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Оскільки окрім чотирьох написів на західному фасаді , мною виявлені ще один напис на північній стіні та один – на східній .',
#   {'entities': [(76, 84, 'inscription')]}),
#  ('Висота від сучасної підлоги 54 см , відстань від лівого кута 33 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Графіті на західному фасаді Софійського собору Графіті № 315 ( табл . ІІ , 1 ) Публікація .',
#   {'entities': [(0, 10, 'inscription'), (47, 56, 'inscription')]}),
#  ('Висота від нижнього краю зондажу 5 см , відстань від лівого краю зондажу 4 см . Опис .',
#   {'entities': [(80, 86, 'inscription')]}),
#  ('Господи , поможи рабу своєму Петру кульгавому писати все добре . Датування .',
#   {'entities': [(65, 76, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ("На фресці прокреслені літери Г\ue002\ue01e , що є традиційним скороченням слова- звернення Г(оспод)[и ] ' Господи ' . Датування .",
#   {'entities': [(108, 119, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 112 см , відстань від правого ребра Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 103 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Висота від сучасної підлоги 94 см , відстань від лівого кута 9 см . Опис .',
#   {'entities': [(68, 74, 'inscription')]}),
#  ('Зважаючи на випадки навмисного паплюження ок- ремих молитовних написів48 , тлумачення графіті як вияву негативного ставлення невідомого автора до Павла є найбільш вірогідним . Датування .',
#   {'entities': [(86, 96, 'inscription'), (176, 187, 'dating_criteria')]}),
#  ('На поверхні стіни прокреслена літера Σ. Датування .',
#   {'entities': [(40, 51, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 574 ( табл . LІV , 2 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 86 см , відстань від лівого кута 19 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Фрагмент напису . Графіті № 4347 ( табл .',
#   {'entities': [(18, 27, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Молитовний напис . Графіті № 518 ( табл . LХІХ , 1 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Графіті № 4261 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Молитовний напис . Графіті № 525 ( табл . LХХІІ , 1 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (54, 68, 'other')]}),
#  ('Фрагмент напису . Графіті № 4297 ( табл .',
#   {'entities': [(18, 27, 'inscription')]}),
#  ('Молитовний напис . Графіті № 579 ( табл . ІІ , 2 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (51, 65, 'other')]}),
#  ('Вірогідно , автор прагнув зобразити святого . Датування .',
#   {'entities': [(46, 57, 'dating_criteria')]}),
#  ("Напис практично повністю знищений вибоями , проте за його збереже- ними складовими можемо реконструювати виконане на фресці дієслово - звернення [ п]ом[ѧ]н[и ] ' пом'яни ' . Датування .",
#   {'entities': [(124, 146, 'other'), (174, 185, 'dating_criteria')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 564 ( табл . LІІ , 5 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Господи , поможи Несторові . Датування .',
#   {'entities': [(29, 40, 'dating_criteria')]}),
#  ("Пам'ятний напис . Графіті № 700 ( табл . LХХХV , 2 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (53, 67, 'other')]}),
#  ('Висота від сучасної підлоги 130 см , відстань від лівого кута 5 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Зважаючи на колективний характер молитовного звернення та вживання у тексті тільки особових імен авторів , доцільно припустити , що у тексті згадуються ченці , які відвідали Святу Софію . Датування .',
#   {'entities': [(188, 199, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 70 см , відстань від лівого кута 7 см . Опис .',
#   {'entities': [(68, 74, 'inscription')]}),
#  ('ГРАФІТІ ПІВНІЧНОЇ СТОРОНИ ЗАХІДНОЇ ЗОВНІШНЬОЇ ГАЛЕРЕЇ',
#   {'entities': [(0, 17, 'inscription')]}),
#  ('Графіті № 570 ( табл . LІV , 3 ) Публікації .',
#   {'entities': [(0, 9, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ("Розташування та ступінь ерозії прорізів дозволяє встановити , що графіті наносили у той час , коли колона перебувала у вертикальному положенні , найімовірніше , до початку XVII ст. ( якщо вона знахо- дилась біля західного порталу , що зруйнувався у цей час ) , або до межі XVII – XVIII ст. , коли масштабні будівельні роботи змінили зовнішній вигляд храму і колони були забрані та перебували на софійському подвір'ї , допоки не були присипані землею до їх виявлення у 1838 р .",
#   {'entities': [(0, 15, 'other'),
#     (65, 81, 'inscription'),
#     (99, 116, 'object_type')]}),
#  ('СІV , 1 ) Розташування .', {'entities': [(10, 24, 'other')]}),
#  ('Графіті № 4270 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Висота від рівня ґрунту 143 см , відстань від лівого ребра стіни 11 см . Опис .',
#   {'entities': [(73, 79, 'inscription')]}),
#  ('Висота від сучасної підлоги 99 см , відстань від лівого кута 65 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ("Пам'ятний напис . Графіті № 4335 ( табл . СХІ , 1 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (52, 66, 'other')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 131 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Господи , поможи рабу своєму Луці грішному . Датування .',
#   {'entities': [(45, 56, 'dating_criteria')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 27 см , відстань від лівого кута 45 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Прикметно , що дві останні літери Йоанн переніс на інший рядок , оскільки йому заважав продовжувати текст запис Григорія ( № 4334 ) .',
#   {'entities': [(106, 120, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 97 см , відстань від лівого кута 62 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ("Пам'ятний напис . Графіті № 4329 ( табл .",
#   {'entities': [(10, 17, 'inscription'), (18, 27, 'inscription')]}),
#  ('Графіті № 442 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('На фресці подвійними рисками прокреслений малюнок чотириконечного хреста , у правій частині перекладини якого намічене декорування у вигляді ламаної лінії . Датування .',
#   {'entities': [(29, 65, 'decoration'), (157, 168, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 80 см , відстань від правого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Молитовний напис . Графіті № 4340 ( табл .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Молитовний напис . Графіті № 719а ( табл .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Висота від сучасної підлоги 84 см , відстань від правого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('ХХІІ , 1 ) Розташування .', {'entities': [(11, 25, 'other')]}),
#  ('Висота від сучасної підлоги 65 см , відстань від лівого кута 33 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ("Пам'ятний напис . Графіті № 696 ( табл . LХХХІV , 1 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (54, 68, 'other')]}),
#  ('На поверхні мармурової колони подвійними замкненими рисками про- креслений чотириконечний хрест .',
#   {'entities': [(75, 97, 'decoration')]}),
#  ('Графіті № 433 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Графіті № 590 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Молитовний напис . Графіті № 516 ( табл . LХVIIІ , 1 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Графіті № 548 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Графіті № 681 ( табл . LХХХІ , 2 ) Розташування .',
#   {'entities': [(0, 9, 'inscription'), (35, 49, 'other')]}),
#  ("Пам'ятний напис . Графіті № 432 ( табл . ХХХ , 2 ) Публікації .",
#   {'entities': [(10, 17, 'inscription'), (18, 27, 'inscription')]}),
#  ("{ помози } ' Господи , поможи ' . Датування .",
#   {'entities': [(34, 45, 'dating_criteria')]}),
#  ("Розташування та ступінь ерозії прорізів дозволяє встановити , що шість з них ( № № 4262–4267 ) з'явились у той час , коли колона перебувала у верти- кальному положенні , найімовірніше , до початку XVII ст. ; два ( № 4269 та № 4270 ) – коли колона вже лежала , тобто , десь до межі XVII – XVIII ст. ; а одне ( № 4268 ) – на- несене правильно по відношенню до вертикального положення колони , проте ступінь ерозії прорізів ( а також палеографія ) вказує , що невдовзі після нанесення напису колона деякий час перебувала на софійському подвір'ї , а згодом була присипана землею .",
#   {'entities': [(0, 15, 'other'),
#     (122, 139, 'object_type'),
#     (240, 250, 'object_type'),
#     (431, 444, 'dating_criteria'),
#     (489, 502, 'object_type')]}),
#  ('Висота від сучасної підлоги 113 см , відстань від лівого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Молитовний напис . Графіті № 4302 ( табл . СІІІ , 1 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (54, 68, 'other')]}),
#  ('Графіті № 438 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Під час дослідження С. Висоцького було опубліковано сім графіті , що тут розташовані – № № 14 , 72–74 , вище , це № № 430–443 , 445–449 , 467–480 , 494 , 582–600 та 600а ( табл . XVIII , 3 ) .',
#   {'entities': [(56, 65, 'inscription')]}),
#  ('На поверхні стіни прокреслена літера Ж. Датування .',
#   {'entities': [(40, 51, 'dating_criteria')]}),
#  ('Загалом на південній стороні апсиди нараховується тридцять шість графіті , яким надані порядкові но- мері від 4312-го до 4347-го ( табл . XVIII , 6 ) .',
#   {'entities': [(65, 74, 'inscription')]}),
#  ('Опис .', {'entities': [(0, 6, 'inscription')]}),
#  ('Графіті № 4257 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 88 см , відстань від лівого кута 64 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Опис .', {'entities': [(0, 6, 'inscription')]}),
#  ('На невеликій ділянці збереженого тиньку за- лишилась тільки одна літера А. Датування .',
#   {'entities': [(75, 86, 'dating_criteria')]}),
#  ('Графіті № 448 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Поверхня фрески вкрита численними вибоями та подряпинами , місцями сильно затерта , особливо в нижній частині та ближче до лівого кута , де знаходиться більшість графіті .',
#   {'entities': [(162, 171, 'inscription')]}),
#  ('Молитовний напис . Графіті № 710 ( табл . LХХХІХ , 1 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (55, 69, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ("Пам'ятний напис . Графіті № 706 ( табл . LХХХVIІ , 2 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (55, 69, 'other')]}),
#  ('Висота від сучасної підлоги 114 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Висота від сучасної підлоги 84 см , відстань від лівого кута 96 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Висота від сучасної підлоги 86 см , відстань від лівого ребра Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Фрагмент напису . Графіті № 4350 ( табл . СХІV , 3 ) Розташування .',
#   {'entities': [(18, 27, 'inscription'), (53, 67, 'other')]}),
#  ('подальше вивчення прорізів довело , що ліва " щогла " щ є засічкою на язичку ѥ , а частина платформи є наслідком невдалої розчистки прорізів , тож на фресці чітко читаються ѥ та дзеркальна ц . Датування .',
#   {'entities': [(46, 53, 'object_type'), (193, 204, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 52 см , відстань від правого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Графіті № 4265 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Він походив з родини Горайнів або Гораймів ( герб Шренява)185 і був стольником Чернігова ( до 1673 р.)186 . Датування .',
#   {'entities': [(108, 119, 'dating_criteria')]}),
#  ('Фрагмент напису . Графіті № 597 ( табл .',
#   {'entities': [(18, 27, 'inscription')]}),
#  ("Пам'ятний напис .", {'entities': [(10, 17, 'inscription')]}),
#  ('Впадає у вічі низка допущених автором помилок та пропущених літер , що видає руку недосвідченого писця . Датування .',
#   {'entities': [(105, 116, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 121 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ("Пам'ятний напис . Графіті № 686 ( табл . LХХХІІ , 1 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (54, 68, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Схожий малюнок хреста вже зустрічався серед графіті Софійського собору , його публікував С.',
#   {'entities': [(44, 63, 'inscription')]}),
#  ('Молитовний напис . Графіті № 470 ( табл .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Графіті № 599 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Графіті № 550 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Висота від сучасної підлоги 88,5 см , відстань від лівого ребра Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('У верхньому рядку помітні пошкод- жені літери ГДИ , у нижньому – МЕ та щогла наступної літери .',
#   {'entities': [(71, 86, 'object_type')]}),
#  ("Напис сильно пошкоджений вибоями , проте за наявними складовими та пошкодженими частинами можемо визначити , що він містив одне дієслово - прохання пом[ѧни ] ' пом'яни ' . Датування .",
#   {'entities': [(128, 155, 'other'), (172, 183, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 105 см , відстань від правого ребра Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ('Господи , поможи рабу своєму Дмитру . Датування .',
#   {'entities': [(38, 49, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Утім , можлива , хоча й менш вірогідна , її ідентифікація і як Ф з незамкненими в нижній частині петлями або глаголичної літери Ⰰ. Датування .',
#   {'entities': [(131, 142, 'dating_criteria')]}),
#  ("За особливостями скорочення повна форма імені особи , за душу якої належало проводити поминальні служби , відновлюється як Михаилъ ' Михайло'183 . Датування .",
#   {'entities': [(147, 158, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ("Оскільки закінчення напису знищене обвалом тиньку , то встановити родове ім'я автора графіті не виявляється за можливе .",
#   {'entities': [(85, 95, 'inscription')]}),
#  ('На поверхні мармурової колони подвійними замкненими рисками про- креслений малюнок хреста - якоря . Датування .',
#   {'entities': [(75, 99, 'decoration'), (100, 111, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('На фресці прокреслені літери Л\ue002В. Датування .',
#   {'entities': [(34, 45, 'dating_criteria')]}),
#  ('Запис лічби . Графіті № 4274 Розташування .',
#   {'entities': [(14, 23, 'inscription'), (29, 43, 'other')]}),
#  ('СХV , 4 ) Розташування .', {'entities': [(10, 24, 'other')]}),
#  ('На фресці прокреслений простий чотириконечний хрест . Датування .',
#   {'entities': [(10, 30, 'execution_technique'),
#     (31, 53, 'decoration'),
#     (54, 65, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 87 см , відстань від правого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Загалом у невеликому відкритому зондажем полі дав- ньої фрески збереглось шість давніх графіті , яким надано номери від 4245-го по Графіті № 4245 ( табл . VІІІ , 1 ) Розташування .',
#   {'entities': [(87, 96, 'inscription'),
#     (131, 140, 'inscription'),
#     (166, 180, 'other')]}),
#  ('Господи , поможи . Датування .',
#   {'entities': [(19, 30, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Молитовний напис . Графіті № 697 ( табл . LХХХІV , 2 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (55, 69, 'other')]}),
#  ('Висота від основи 209 см . Опис .',
#   {'entities': [(27, 33, 'inscription')]}),
#  ('Висота від сучасної підлоги 75 см , відстань від лівого кута 9 см . Опис .',
#   {'entities': [(68, 74, 'inscription')]}),
#  ("Зважаючи на наявність титла та вибоїну перед першою літерою , текст найвірогідніше реконструювати як запис імені [ І]ꙍа(нъ ) ' Йоанн ' . Датування .",
#   {'entities': [(101, 112, 'inscription'), (137, 148, 'dating_criteria')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Ох , сороковиця , прости мене , Кузьму , ох . Датування .',
#   {'entities': [(46, 57, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Графіті на фресці з зображенням невідомих святителів Фреска розташована на південній стороні апсиди хрещальні , образи святих на- разі не ідентифіковані .',
#   {'entities': [(0, 10, 'inscription'), (53, 71, 'object_type')]}),
#  ("Пам'ятний напис . Графіті № 4298 ( табл . СІ , 3 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (51, 65, 'other')]}),
#  ('Висота від сучасної підлоги 95 см , відстань від лівого кута 131 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Цитати та посилання на твори книжної писемності . і становлення української літератури , К. 1988 , с . 29–30 . Графіті № 74 ( табл . ХХVІІ , 2 ) Публікації .',
#   {'entities': [(111, 120, 'inscription')]}),
#  ('Особу автора наразі ідентифікувати не вдалося . Датування .',
#   {'entities': [(48, 59, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 101 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Висота від сучасної підлоги 72 см , відстань від лівого кута 45 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Молитовний напис .', {'entities': [(11, 18, 'inscription')]}),
#  ('Графіті № 472 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Молитовний напис . Графіті № 719в ( табл .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('На фресці подвійними замкненими рисками прокреслена відкрита донизу овальна фігура , що має вигляд підкови . Датування .',
#   {'entities': [(109, 120, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 51 см , відстань від лівого кута 19 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('З розбивкою на слова та відновленням втрачених фрагментів наявний текст ви- глядає таким чином : С(вѧ)тие м моу[ченикъ ] . Святі 40 мучеників . Датування .',
#   {'entities': [(144, 155, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 102 см , відстань від лівого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Висота від сучасної підлоги 117,5 см , відстань від лівого кута Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ('Висота від сучасної підлоги 98 см , відстань від лівого кута 342 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ("Пам'ятний напис . Графіті № 4333 ( табл .",
#   {'entities': [(10, 17, 'inscription'), (18, 27, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 107 см , відстань від лівого кута 25 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Трирядковий запис обчислення кількості проведених поминальних служб .',
#   {'entities': [(12, 49, 'inscription_type')]}),
#  ('СХІІІ , 4 ) Розташування .', {'entities': [(12, 26, 'other')]}),
#  ('Графіті № 718 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Графіті № 435 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('На фресці прокреслений простий чотириконечний хрест . Датування .',
#   {'entities': [(10, 30, 'execution_technique'),
#     (31, 53, 'decoration'),
#     (54, 65, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 110 см , відстань від правого ребра Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ("На фресці прокреслені літери Г\ue002\ue01eПО , що є незавершеною формою тради- ційної формули Г(оспод)и по{мози } ' Господи , поможи ' . Датування .",
#   {'entities': [(127, 138, 'dating_criteria')]}),
#  ('Вочевидь , напис був затертий під час реставраційних робіт , коли з фрески зні- мався олійний живопис .',
#   {'entities': [(11, 20, 'inscription'),
#     (21, 33, 'preservation_state'),
#     (86, 101, 'material')]}),
#  ('ХХХІ , 2 ) Розташування .', {'entities': [(11, 25, 'other')]}),
#  ('Висота від сучасної підлоги 99 см , відстань від лівого кута 505 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Молитовний напис . Графіті № 524 ( табл . LХХ , 3 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (52, 66, 'other')]}),
#  ('Графіті № 4263 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('ХХІ , 2 ) Розташування .', {'entities': [(10, 24, 'other')]}),
#  ('Висота від сучасної підлоги 96 см , відстань від лівого кута 113 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ("За наявними складовими напис може бути прочитаний як особове та родове імена автора Maciej Domansky ' Мацей Доманський ' .",
#   {'entities': [(23, 33, 'inscription')]}),
#  ('Графіті № 600а ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Висота від основи 107 см . Опис .',
#   {'entities': [(27, 33, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Окрім самого тіла колони поруч експонується її мармурова база , у верхній частині якої поставлена робоча по- значка у вигляді літери Y ( табл . ХІ , 3 ) .',
#   {'entities': [(47, 63, 'object_type')]}),
#  ("Її зв'язок з основ- ним текстом лишається невизначеним . Датування .",
#   {'entities': [(57, 68, 'dating_criteria')]}),
#  ("Незважаючи на пошкодження тиньку іншим графіті , складові напису збе- реглись добре і чітко простежуються , завдяки чому можемо встановити , що тут була виконана традиційна форма молитви Госьподи помоꙁи ' Господи , поможи ' . Датування .",
#   {'entities': [(39, 48, 'inscription'), (226, 237, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 83,5 см , відстань від правого кута Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ('Графіті № 488 ( табл . ХХ , 1 ) Розташування .',
#   {'entities': [(0, 9, 'inscription'), (32, 46, 'other')]}),
#  ("Пам'ятний напис . Графіті № 4342 ( табл .",
#   {'entities': [(10, 17, 'inscription'), (18, 27, 'inscription')]}),
#  ('Молитовний напис . Графіті № 41 ( табл . LVІІ , 2 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Висота від сучасної підлоги 83 см , відстань від правого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ("Господи , пом'яни ... Датування .",
#   {'entities': [(22, 33, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 96 см , відстань від лівого кута 56 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ("Пам'ятний напис . І.3 .", {'entities': [(10, 17, 'inscription')]}),
#  ('Окрім самого тіла колони поруч експонується її мармурова база , у верхній частині якої поставлена робоча позначка у вигляді літери П ( табл . ХІ , 5 ) .',
#   {'entities': [(47, 63, 'object_type')]}),
#  ('Графіті на фресці з зображенням орнаменту Фреска розташована у північно - східному куті хрещальні , на південній грані за- хідної лопатки виступу стіни .',
#   {'entities': [(0, 10, 'inscription'), (42, 60, 'object_type')]}),
#  ("Пам'ятний напис . Графіті № 4324 ( табл . СVІІІ , 2 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (54, 68, 'other')]}),
#  ('Графіті № 573 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Поверхня стіни в місці розташування графіті затерта та пошкоджена ви- боями , тому закінчення другого рядка не збереглось : г͠\ue01fпомоꙁ\ue01f | рабоусвоемоудъм\ue01f-р--',
#   {'entities': [(36, 51, 'inscription')]}),
#  ('На поверхні мармурової колони прокреслений простий чотириконечний хрест . Датування .',
#   {'entities': [(30, 50, 'execution_technique'),
#     (51, 73, 'decoration'),
#     (74, 85, 'dating_criteria')]}),
#  ('СХІІІ , 3 ) Розташування .', {'entities': [(12, 26, 'other')]}),
#  ("Біля останнього слова попереднього напису в два рядки виконане слово м(оу)ч(е)н(и)ка ' мучеників ' , яке слід тлумачити як виправлення до тексту графіті № 502 .",
#   {'entities': [(145, 154, 'inscription')]}),
#  ('СІ , 2 ) Розташування .', {'entities': [(9, 23, 'other')]}),
#  ('Молитовний напис . Графіті № 4349 ( табл . СХІV , 2 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (54, 68, 'other')]}),
#  ('Незважаючи на пошкодження поверхні фрески , напис в цілому зберігся доволі добре : -омен\ue01fгⷣ\ue003\ue01fрабꙋсвоюѯѣ-\ue01fю\ue01fрабꙋсвоюꙍгаф\ue01fю З розбивкою на слова та відновленням втрачених фрагментів текст виглядає таким чином : [ П]омени Г(оспо)ди рабꙋ свою Ѯѣ[н]ию и рабꙋ свою Ꙍгафию .',
#   {'entities': [(44, 51, 'inscription')]}),
#  ('Висота від сучасної підлоги 101 см , відстань від лівого кута 20 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('На фресці прокреслена літера П. Датування .',
#   {'entities': [(32, 43, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 100 см , відстань від лівого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Відтак , означене графіті пояснює сенс зображеного на фресці . Датування .',
#   {'entities': [(18, 33, 'inscription'), (63, 74, 'dating_criteria')]}),
#  ('Збереженість напису доволі добра , його складові чітко читаються як тра- диційне молитовне звернення : Сп(а)си мѧ. Спаси мене .',
#   {'entities': [(81, 102, 'inscription_type')]}),
#  ('Висота від сучасної підлоги 123 см , відстань від правого ребра Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ('Графіті № 2030б ( табл . СХХІ ) Розташування .',
#   {'entities': [(0, 9, 'inscription'), (32, 46, 'other')]}),
#  ('Найвірогідніше реконструювати текст як подвоєний запис особового та родо- вого імен автора : Іоанъ Іоан(ъ ) М(а)рк(овічь ) М[арко]вічь .',
#   {'entities': [(49, 64, 'inscription')]}),
#  ('Висота від рівня ґрунту 118 см , відстань від лівого кута стіни Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 85 см , відстань від правого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 79 см , відстань від правого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('ХХХ , 1)74 Розташування .', {'entities': [(11, 25, 'other')]}),
#  ('Висота від рівня давньої підлоги 175 см , відстань від лі- вого кута стіни 116 см . Опис .',
#   {'entities': [(84, 90, 'inscription')]}),
#  ("Пам'ятний напис . Графіті № 4337 ( табл . СХІ , 3 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (52, 66, 'other')]}),
#  ('Оскільки ця колона тонша і довша за іншу , в іс- торіографії можна зустріти думку про приналежність цієї колони до оздоблення Десятинної церкви , яка походить з розкопок 1824 чи 1826 рр.43',
#   {'entities': [(12, 24, 'object_type')]}),
#  ('Висота від основи 117 см . Опис .',
#   {'entities': [(27, 33, 'inscription')]}),
#  ('На фресці прокреслений квадрат з крапкою посередині . Датування .',
#   {'entities': [(10, 30, 'execution_technique'),
#     (54, 65, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 54 см , відстань від лівого кута 58 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Графіті № 4355 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Молитовний напис . Графіті № 40 ( табл . LVІІ , 1 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Висота від сучасної підлоги 96 см , відстань від лівого кута 58 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Висота від сучасної підлоги 38 см , відстань від лівого кута 30 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Між ним та первісною стіною знахо- диться невелика шпарина , ширина якої не дозволяє ані сфотографувати графіті , що знаходяться тут , ані зняти якісні кальки з поверхні фрески .',
#   {'entities': [(104, 113, 'inscription')]}),
# ...
#   {'entities': [(33, 42, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ("Пом'яни , Господи , раба ... Датування .",
#   {'entities': [(29, 40, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Фрагмент напису . Графіті № 4289 ( табл .',
#   {'entities': [(18, 27, 'inscription')]}),
#  ('Висота від сучасної підлоги 91 см , відстань від лівого кута 54 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Молитовний напис . Графіті № 709 ( табл . LХХХVIІІ , 2 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (57, 71, 'other')]}),
#  ('Цим графіті надані порядкові номері від Графіті № 4281 ( табл .',
#   {'entities': [(4, 18, 'inscription'), (40, 49, 'inscription')]}),
#  ('Висота від рівня давньої підлоги 193 см , відстань від лі- вого кута стіни 224 см . Опис .',
#   {'entities': [(84, 90, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Права частина пошкоджена вибоєм , проте за наявними фрагментами мо- жемо встановити , що тут була прокреслена літера М. Датування .',
#   {'entities': [(120, 131, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 68 см , відстань від лівого кута 64 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Висота від сучасної підлоги 143 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Висота від сучасної підлоги 92 см , відстань від лівого кута 24 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Висота від сучасної підлоги 57 см , відстань від лівого кута 56 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Графіті № 672 ( табл . LХХІХ , 4 ) Розташування .',
#   {'entities': [(0, 9, 'inscription'), (35, 49, 'other')]}),
#  ('Висота від сучасної підлоги 45 см , відстань від лівого кута 35 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Висота від сучасної підлоги 84 см , відстань від лівого ребра 37 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Графіті № 692 ( табл . LХХХІІІ , 2 ) Розташування .',
#   {'entities': [(0, 9, 'inscription'), (37, 51, 'other')]}),
#  ('Графіті № 581 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 83 см , відстань від лівого кута 519 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Графіті № 445 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Графіті № 493 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Графіті № 4327 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Відтак , напис міг бути виконаний автором тільки тоді , коли він знаходився на риштуванні .',
#   {'entities': [(9, 18, 'inscription')]}),
#  ('На підставі інформації графіті № 4252 образ цього незбереженого святого може бути ідентифікований як св .',
#   {'entities': [(23, 32, 'inscription')]}),
#  ('Молитовний напис . Графіті № 468 ( табл .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Господи , поможи рабу своєму Луці . Датування .',
#   {'entities': [(36, 47, 'dating_criteria')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ("На фресці прокреслене дієслово - прохання помꙗни ' помяни ' . Датування .",
#   {'entities': [(22, 48, 'other'), (62, 73, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 83 см , відстань від лівого кута 521 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Висота від сучасної підлоги 133 см , відстань від лівого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Висота від сучасної підлоги 30,5 см , відстань від лівого кута 56 см . Опис .',
#   {'entities': [(71, 77, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Графіті на мармуровій колоні з експозиції у Трапезній церкві Фрагмент мармурової колони довжиною близько 1,5 м , що нині експонується у Трапезній церкві Національного заповідника " Софія Київська " ( табл . ХVI , 1 ) , як вва- жають дослідники , також походить з Софійського собору і може бути віднесений до тих мармурових деталей , що були виявлені М. Щуруповим на подвір\'ї Софійського собору у 1838 р.45',
#   {'entities': [(0, 10, 'inscription')]}),
#  ('Висота від сучасної підлоги 64 см , відстань від лівого кута 41,5 см . Опис .',
#   {'entities': [(71, 77, 'inscription')]}),
#  ('Молитовний напис . Графіті № 702 ( табл . LХХХVІ , 1 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (55, 69, 'other')]}),
#  ("Пам'ятний напис . Графіті № 4320 ( табл . СVІІ , 3 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (53, 67, 'other')]}),
#  ('Висота від сучасної підлоги 97,5 см , відстань від лівого кута Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Графіті № 4254 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('На поверхні стіни у стовпчик прокреслені літери ВН . Датування .',
#   {'entities': [(53, 64, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 4252 ( табл . Х ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (47, 61, 'other')]}),
#  ('Висота від сучасної підлоги 89 см , відстань від правого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ("На фресці помітні виконані у стовпчик літери ПО та М\ue01e , які слід розгля- дати як незавершений або скорочений запис дієслова - прохання поми{лоуи } ' помилуй ' . Датування .",
#   {'entities': [(109, 144, 'inscripiton type'),
#     (161, 172, 'dating_criteria')]}),
#  ('Опис .', {'entities': [(0, 6, 'inscription')]}),
#  ('Висота від сучасної підлоги 97 см , відстань від лівого кута 4 см . Опис .',
#   {'entities': [(68, 74, 'inscription')]}),
#  ('Во- чевидь , сцена має зображати диявола в образі змія - спокусника . Датування .',
#   {'entities': [(70, 81, 'dating_criteria')]}),
#  ('Графіті № 689 ( табл . LХХХІІ , 4 ) Розташування .',
#   {'entities': [(0, 9, 'inscription'), (36, 50, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ("Пам'ятний напис . Графіті № 598 ( табл . ХLIV , 5 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (52, 66, 'other')]}),
#  ('На поверхні мармурової колони прокреслені літери ИС , які , вірогідно , слід розглядати як складову теонімограми імені " Ісус " . Датування .',
#   {'entities': [(130, 141, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 43 см , відстань від правого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Фрагмент напису . Графіті № 4328 ( табл . СVІІІ , 6 ) Розташування .',
#   {'entities': [(18, 27, 'inscription'), (54, 68, 'other')]}),
#  ("Пам'ятний напис . Графіті № 623 ( табл . LХХVІІ , 3 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (54, 68, 'other')]}),
#  ('Графіті № 668 ( табл . LХХVІІІ , 6 )',
#   {'entities': [(0, 9, 'inscription')]}),
#  ("ОписПрава частина напису знищена обвалом тиньку , за збереженими фрагмен- тами можемо встановити , що тут знаходилась традиційна формула Г(оспод)и п[омози ] ' Господи поможи ' . Датування .",
#   {'entities': [(178, 189, 'dating_criteria')]}),
#  ('ХХІІ , 2 ) Розташування .', {'entities': [(11, 25, 'other')]}),
#  ('Тиньк в місці розташування напису сильно пошкоджений , збереглась тільки літера М із дуже провисаючою петлею , та фрагменти інших літер обабіч неї . Датування .',
#   {'entities': [(0, 7, 'material'), (149, 160, 'dating_criteria')]}),
#  ('Опис .', {'entities': [(0, 6, 'inscription')]}),
#  ('Висота від сучасної підлоги 87 см , відстань від лівого кута 11,5 см . Опис .',
#   {'entities': [(71, 77, 'inscription')]}),
#  ('Особливості розташування напису - графіті не лишають сумніву в тому , що його було нанесено під час виконання оздоблювальних робіт у хрещальні , коли тут стояло риштування та розписувалась верхня частина композиції " Сорок мучеників Севас- тійських " , що складалась з мандорли із зображенням Ісуса Христа у центрі зверху та вінців мучеників обабіч неї нижче .',
#   {'entities': [(34, 44, 'inscription')]}),
#  ('Молитовний напис . Графіті № 563 ( табл . LІІ , 4 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Молитовний напис . Графіті № 553 ( табл . L , 1 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ("Тим не менше , його збереженість задовільна й текст повністю підлягає прочитанню : Anna Laszczo[wa ] ' Анна Лящова ' .",
#   {'entities': [(20, 43, 'preservation_state')]}),
#  ('Графіті № 441 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Висота від сучасної підлоги 244 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ("Збереженість напису доволі добра , його складові чітко простежуються як запис особового та родового імені автора Lucas Horain ' Лукаш Горайн ' .",
#   {'entities': [(72, 87, 'inscription')]}),
#  ('Висота від сучасної підлоги 75,5 см , відстань від лівого ребра Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ('На фресці прокреслена літера П\ue00a. Датування .',
#   {'entities': [(33, 44, 'dating_criteria')]}),
#  ('Особа автора наразі не ідентифікована . Датування . 1670 р . ; за прямим датуванням . Категорія .',
#   {'entities': [(40, 51, 'dating_criteria')]}),
#  ('На поверхні ще вологого фрескового тиньку було прокреслене велике коло , всередині якого містилося приблизно вдвічі менше коло . Датування .',
#   {'entities': [(129, 140, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 449 ( табл .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Графіті № 534 ( табл . LХХV , 3 ) Розташування .',
#   {'entities': [(0, 9, 'inscription'), (34, 48, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Поверхня стіни довкола них вказує , що напис із самого початку містив тільки ці дві складові .',
#   {'entities': [(39, 47, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('На фресці прокреслений простий чотириконечний хрест . Датування .',
#   {'entities': [(10, 30, 'execution_technique'),
#     (31, 53, 'decoration'),
#     (54, 65, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 475 ( табл . ХХХVІІ , 5 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (55, 69, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 101,5 см , відстань від лівого кута Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ('Молитовний напис . Графіті № 4296 ( табл . СІ , 1 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (52, 66, 'other')]}),
#  ('Незважаючи на пошкодження тиньку , напис чітко читається : Писал я . Писав я . Датування .',
#   {'entities': [(35, 46, 'inscription'), (79, 90, 'dating_criteria')]}),
#  ('Вочевидь , напис лишився не- завершеним . Датування .',
#   {'entities': [(11, 24, 'inscription'), (42, 53, 'dating_criteria')]}),
#  ("Пам'ятний напис . Графіті № 4330 ( табл .",
#   {'entities': [(10, 17, 'inscription'), (18, 27, 'inscription')]}),
#  ('Молитовний напис . Графіті № 473 ( табл . ХХХVІІ , 3 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (55, 69, 'other')]}),
#  ('Запис лічби . Графіті № 4276 Розташування .',
#   {'entities': [(14, 23, 'inscription'), (29, 43, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ("На фресці прокреслене дієслово - прохання помени ' пом'яни ' . Датування .",
#   {'entities': [(22, 48, 'other'), (63, 74, 'dating_criteria')]}),
#  ('Ця колона , вочевидь , вже в давнину була зруйнована і її використали для виготовлення надгробку , нанісши на поверхню напис , від якого залишилась тільки права частина .',
#   {'entities': [(3, 11, 'object_type'), (119, 126, 'inscription')]}),
#  ('Графіті № 4290 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Молитовний напис . Графіті № 683 ( табл . LХХХІ , 4 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (54, 68, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Графіті № 4258 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Висота від сучасної підлоги 120 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('ХХХVІ , 2 ) Розташування .', {'entities': [(12, 26, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 85 см , відстань від лівого ребра 28 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Висота від сучасної підлоги 66 см , відстань від правого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 117 см , відстань від лівого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Висота від сучасної підлоги 36 см , відстань від правого кута 12 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Висота від сучасної підлоги 131 см , відстань від лівого кута 4 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Висота від сучасної підлоги 68,5 см , відстань від правого ребра Опис .',
#   {'entities': [(65, 71, 'inscription')]}),
#  ('Висота від сучасної підлоги 110 см , відстань від правого ребра Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ('Висота від сучасної підлоги 91 см , відстань від лівого ребра 18 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Висота від сучасної підлоги 34 см , відстань від лівого кута 13,5 см . Опис .',
#   {'entities': [(71, 77, 'inscription')]}),
#  ('У написі прикметним є неузгодженість відмінків між дієсловом та рештою тек- сту , що видає руку недосвідченого писця . Датування .',
#   {'entities': [(119, 130, 'dating_criteria')]}),
#  ('На початку рядка читається літера К , дали знаходиться вибій , який за контурами дозволяє реконструювати тут літеру У або Р , за нею – літери ЛИН , далі знов міститься округлий вибій , який знищив ще одну літеру . Датування .',
#   {'entities': [(214, 225, 'dating_criteria')]}),
#  ("Пам'ятний напис . Графіті № 703 ( табл . LХХХVІ , 2 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (54, 68, 'other')]}),
#  ('Також на досліджуваній поверхні стіни знаходиться велика кількість сучасних написів , переважно залишених відвідувачами Софії Київської у другій половини Графіті № 39 ( табл . LVІ , 1 ) Публікації .',
#   {'entities': [(154, 163, 'inscription')]}),
#  ('Фрагмент напису . Графіті № 674 ( табл . LХХІХ , 6 ) Розташування .',
#   {'entities': [(18, 27, 'inscription'), (53, 67, 'other')]}),
#  ("Пам'ятний напис . Графіті № 4315 ( табл . СVІ , 2 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (52, 66, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 104 см , відстань від лівого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Молитовний напис . Графіті № 582 ( табл . ХL , 2 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (51, 65, 'other')]}),
#  ('ХІІ , 2 ) Розташування .', {'entities': [(10, 24, 'other')]}),
#  ('Фрагмент напису . Графіті № 4294 ( табл .',
#   {'entities': [(18, 27, 'inscription')]}),
#  ('На поверхні мармурової колони подвійними незамкненими рисками про- креслений чотириконечний хрест .',
#   {'entities': [(77, 99, 'decoration')]}),
#  ('Висота від нижнього краю зондажу 3 см , відстань від лівого краю зондажу 8 см . Опис .',
#   {'entities': [(80, 86, 'inscription')]}),
#  ...]

# %% [markdown]
# # Prepare SpaCy NER model

# %%
import spacy
from spacy.training import Example

# https://towardsdatascience.com/train-ner-with-custom-training-data-using-spacy-525ce748fab7

# Load a blank model or a pre-existing model for your language
nlp = spacy.blank('uk')  # Replace 'en' with your language code if different

# Create the NER component if it doesn't exist
if 'ner' not in nlp.pipe_names:
    ner = nlp.add_pipe('ner')
else:
    ner = nlp.get_pipe('ner')

# Add labels
for _, annotations in train_data:
    for ent in annotations.get('entities'):
        ner.add_label(ent[2])

# %% [markdown]
# # Train a SpaCy NER model

# %%
from spacy.util import minibatch, compounding

optimizer = nlp.initialize()

# Use the training data
for epoch in range(25):
    random.shuffle(train_data)
    losses = {}
    batches = minibatch(train_data, size=compounding(4., 32., 1.001))
    for batch in batches:
        for text, annotations in batch:
            doc = nlp.make_doc(text)
            example = Example.from_dict(doc, annotations)
            nlp.update([example], drop=0.5, sgd=optimizer, losses=losses)
    print(f"Losses at epoch {epoch}: {losses}")
# Out:
# Losses at epoch 0: {'ner': 1127.8061195828202}
# Losses at epoch 1: {'ner': 442.0105688380212}
# Losses at epoch 2: {'ner': 421.4218361339304}
# Losses at epoch 3: {'ner': 435.41170710475456}
# Losses at epoch 4: {'ner': 367.6602700794566}
# Losses at epoch 5: {'ner': 327.9406950034582}
# Losses at epoch 6: {'ner': 257.15945962447097}
# Losses at epoch 7: {'ner': 353.95736190309486}
# Losses at epoch 8: {'ner': 264.4722774302612}
# Losses at epoch 9: {'ner': 269.674714384915}
# Losses at epoch 10: {'ner': 215.7394853181311}
# Losses at epoch 11: {'ner': 204.718010064536}
# Losses at epoch 12: {'ner': 213.68417723186192}
# Losses at epoch 13: {'ner': 177.83682211562513}
# Losses at epoch 14: {'ner': 171.88516615676912}
# Losses at epoch 15: {'ner': 165.11581794200958}
# Losses at epoch 16: {'ner': 145.93355866586575}
# Losses at epoch 17: {'ner': 177.99353892080586}
# Losses at epoch 18: {'ner': 143.5537956684429}
# Losses at epoch 19: {'ner': 162.1177910293382}
# Losses at epoch 20: {'ner': 192.0279291069965}
# Losses at epoch 21: {'ner': 121.52819411375815}
# Losses at epoch 22: {'ner': 145.30082608073877}
# Losses at epoch 23: {'ner': 158.73521620493216}
# Losses at epoch 24: {'ner': 167.60833921930646}

# %% [markdown]
# # Evaluation on the test data

# %% [markdown]
# ## Prepare test data predictions

# %%
def transform_to_iob(nlp_model, data):
    transformed_data = []
    for text, annot in data:
        doc = nlp_model(text)
        # Extract IOB tokens from the SpaCy doc
        iob_tokens = [f"{t.ent_iob_}-{t.ent_type_}" if t.ent_type_ else t.ent_iob_ for t in doc]
        transformed_data.append(iob_tokens)
    return transformed_data

predictions_iob = transform_to_iob(nlp, test_data)

# %%
predictions_iob[:3]
# Out:
# [['B-inscription',
#   'I-inscription',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-object_type',
#   'I-object_type',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-inscription',
#   'I-inscription',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'B-inscription',
#   'I-inscription',
#   'B-inscription',
#   'I-inscription',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['B-dating_criteria', 'I-dating_criteria']]

# %% [markdown]
# ## Prepare the true test data (groundtruth)

# %%
def transform_annotations_to_iob(data, nlp):
    iob_annotations = []

    for text, annot in data:
        doc = nlp.make_doc(text)  # Create a doc from text to ensure correct offsets
        tags = ['O'] * len(doc)  # Initialize tags with 'O'

        entities = annot['entities']
        # Convert character offsets to token offsets
        for start_char, end_char, label in entities:
            start_token, end_token = None, None
            for token_index, token in enumerate(doc):
                # Check if we've found the start token
                if token.idx == start_char:
                    start_token = token_index
                # Check if the current token extends beyond the start of the end_char range
                if token.idx + len(token) == end_char:
                    end_token = token_index
                # If the token encompasses the end character
                if token.idx + len(token) > end_char and end_token is None:
                    end_token = token_index

            if start_token is not None and end_token is not None:
                tags[start_token] = f"B-{label}"
                for i in range(start_token + 1, end_token + 1):
                    tags[i] = f"I-{label}"

        iob_annotations.append(tags)
    return iob_annotations

references_iob = transform_annotations_to_iob(test_data, nlp)

# %% [markdown]
# ## Results evaluation

# %%
# !pip install seqeval

# %%
from seqeval.metrics import classification_report, accuracy_score, f1_score

# Assuming predictions_iob and references_iob are ready
results = classification_report(references_iob, predictions_iob, digits=4)
accuracy = accuracy_score(references_iob, predictions_iob)
f1 = f1_score(references_iob, predictions_iob)

print("Classification Report:\n", results)
print("Accuracy Score:", accuracy)
print("F1 Score:", f1 * 100.0, "%")
# Out:
# Classification Report:
#                       precision    recall  f1-score   support
#
#     dating_criteria     1.0000    1.0000    1.0000        37
#          decoration     1.0000    0.9000    0.9474        10
# execution_technique     0.8000    0.8889    0.8421         9
#         inscription     0.9901    0.9901    0.9901       101
#            material     1.0000    1.0000    1.0000         1
#            monument     0.0000    0.0000    0.0000         2
#         object_type     0.8571    0.8571    0.8571         7
#               other     1.0000    0.9722    0.9859        36
#              symbol     0.0000    0.0000    0.0000         1
#
#           micro avg     0.9800    0.9608    0.9703       204
#           macro avg     0.7386    0.7343    0.7358       204
#        weighted avg     0.9667    0.9608    0.9635       204
#
# Accuracy Score: 0.9930209371884346
# F1 Score: 97.02970297029701 %
# C:\Users\lyh\anaconda3\envs\ml-project2\lib\site-packages\seqeval\metrics\v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
model_path = "model/first_model"
nlp.to_disk(model_path)

# %% [markdown]
# # Example - how to use it

# %%
import spacy
model_path = 'model/first_model'
nlp = spacy.load(model_path)

# %%
text = "мурування апсиди ХІІ ст. г давні ХІ ст. пройми арок галереї закла-."
doc = nlp(text)
print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
# Out:
# Entities [('мурування апсиди', 'object_type')]

# %%
for text, _ in test_data[:5]:
    doc = nlp(text)
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
    print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc if 'inscription' in t.ent_type_])
# Out:
# Entities [('прокреслений малюнок шестикінечної', 'decoration'), ('Датування .', 'dating_criteria')]
# Tokens []
# Entities [('Розташування .', 'other')]
# Tokens []
# Entities [('Опис .', 'inscription')]
# Tokens [('Опис', 'inscription', 3), ('.', 'inscription', 1)]
# Entities [('Розташування .', 'other')]
# Tokens []
# Entities [('Розташування .', 'other')]
# Tokens []
