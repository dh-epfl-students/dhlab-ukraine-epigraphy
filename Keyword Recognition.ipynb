# %%
# # Correcting the initial generated file


# def process_file(input_filename, output_filename):
#     with open(input_filename, 'r', encoding='utf-8') as file:
#         lines = file.readlines()

#     with open(output_filename, 'w', encoding='utf-8') as file:
#         for line in lines:
#             if line.strip() == '"':
#                 file.write("\n")  # write a newline for lines that are just a quote
#             elif line.strip() == '",O':
#                 continue
#             else:
#                 corrected_line = line.replace(',', '\t')
#                 file.write(corrected_line)

# process_file('data/ner/tokens_IOB.csv', 'data/ner/tokens_IOB_correct.csv')

# %%
import random

def read_and_split_data(input_filename, train_ratio=0.8, dev_ratio=0.1, test_ratio=0.1):
    # Ensure the ratios sum to 1
    assert train_ratio + dev_ratio + test_ratio == 1
    
    # Read and process the file
    with open(input_filename, 'r', encoding='utf-8') as file:
        content = file.read()
    
    # Split content into sentences based on newlines
    sentences = content.strip().split('\n\n')

    # Shuffle the sentences randomly for a fair split
    random.shuffle(sentences)

    # Calculate split indices
    total = len(sentences)
    train_end = int(total * train_ratio)
    dev_end = train_end + int(total * dev_ratio)
    
    # Create splits
    train_sentences = sentences[:train_end]
    dev_sentences = sentences[train_end:dev_end]
    test_sentences = sentences[dev_end:]

    # Save each split to a different file
    with open('data/final/splits/train.csv', 'w', encoding='utf-8') as file:
        file.write('\n\n'.join(train_sentences))
    with open('data/final/splits/dev.csv', 'w', encoding='utf-8') as file:
        file.write('\n\n'.join(dev_sentences))
    with open('data/final/splits/test.csv', 'w', encoding='utf-8') as file:
        file.write('\n\n'.join(test_sentences))

read_and_split_data('data/final/data.tsv')

# %%
def load_data(filename):
    with open(filename, 'r', encoding='utf-8') as file:
        data = file.read().strip().split('\n\n')  # Splitting data by double newlines

    formatted_data = []
    for record in data:
        text, entities = '', []
        lines = record.split('\n')
        start = 0  # Initialize start of the first token
        entity_start = None  # Initialize the start of an entity
        entity_type = None  # Initialize the entity type
        for line in lines:
            parts = line.split('\t')
            if len(parts) >= 2:  # Ensure there's at least a token and a tag
                token, tag = parts[0], parts[1]
                # Update text with token followed by space
                text += token + ' '
                end = start + len(token)  # End index of the current token
                if tag.startswith('B-') or tag.startswith('I-'):  # Check if the tag indicates an entity
                    if tag.startswith('B-'):
                        # If there was a previous entity, append it
                        if entity_start is not None:
                            entities.append((entity_start, prev_end, entity_type))
                        # Start new entity
                        entity_start = start
                        entity_type = tag.split('-')[1]
                    if tag.startswith('I-') and entity_start is not None:
                        # Continue the entity
                        entity_type = tag.split('-')[1]  # Update the type if needed (typically not necessary)
                else:
                    # If ending part of entity, append it
                    if entity_start is not None:
                        entities.append((entity_start, end, entity_type))
                        entity_start = None  # Reset for the next entity

                # Prepare for next token
                start = end + 1
                prev_end = end  # Remember the end of the last token

        # Check for any trailing entity at the end
        if entity_start is not None:
            entities.append((entity_start, prev_end, entity_type))

        # Append the parsed data if there are entities
        if entities:
            formatted_data.append((text.strip(), {'entities': entities}))

    return formatted_data

# Load the data
train_data = load_data('data/final/splits/train.csv')
dev_data = load_data('data/final/splits/dev.csv')
test_data = load_data('data/final/splits/test.csv')

# %%
train_data
# Out:
# [('Висота від сучасної підлоги 133 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('ХІІ , 2 ) Розташування .', {'entities': [(10, 24, 'other')]}),
#  ("Пам'ятний напис . Графіті № 4298 ( табл . СІ , 3 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (51, 65, 'other')]}),
#  ('Висота від основи 107 см . Опис .',
#   {'entities': [(27, 33, 'inscription')]}),
#  ("Автор напису походив з родини Доманських ( герб Ларисса)196 , особа з таким ім'ям згадується наприкінці XVI ст.197 , що не суперечить датуванню графіті .",
#   {'entities': [(144, 153, 'inscription')]}),
#  ('Молитовний напис . Графіті № 224 ( табл . LХ , 1 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Молитовний напис . Графіті № 588 ( табл . ХLII , 1 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (53, 67, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ("Біля останнього слова попереднього напису в два рядки виконане слово м(оу)ч(е)н(и)ка ' мучеників ' , яке слід тлумачити як виправлення до тексту графіті № 502 .",
#   {'entities': [(145, 154, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 41 см , відстань від правого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Друга чверть XІІ – початок XІІI ст. ; за формою написання а з видов- женою спинкою , в , верхня петля якої ширша за нижню , нахиленої праворуч е , прямолі- нійної р з петлею кутом вгору ; з притаманних цьому періоду палеографічних ознак випадає тільки літера б , що має петлю з двома заломами , але це наслідок невдалого ви- конання літери автором напису . Категорія .',
#   {'entities': [(96, 106, 'other')]}),
#  ('Відтак , напис міг бути виконаний автором тільки тоді , коли він знаходився на риштуванні .',
#   {'entities': [(9, 18, 'inscription')]}),
#  ('Висота від сучасної підлоги 114,5 см , відстань від лівого ребра Опис .',
#   {'entities': [(65, 71, 'inscription')]}),
#  ('Висота від сучасної підлоги 46,5 см , відстань від лівого кута Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 156 ( табл . LVІІІ , LІХ ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 112 см , відстань від правого ребра Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ('У верхньому рядку помітні пошкод- жені літери ГДИ , у нижньому – МЕ та щогла наступної літери .',
#   {'entities': [(71, 86, 'object_type')]}),
#  ('На поверхні мармурової колони прокреслений простий чотириконечний хрест . Датування .',
#   {'entities': [(30, 50, 'execution_technique'),
#     (51, 73, 'decoration'),
#     (74, 85, 'dating_criteria')]}),
#  ('Фрагмент напису . Графіті № 674 ( табл . LХХІХ , 6 ) Розташування .',
#   {'entities': [(18, 27, 'inscription'), (53, 67, 'other')]}),
#  ('Висота від сучасної підлоги 84 см , відстань від лівого ребра 37 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Молитовний напис . Графіті № 567 ( табл . LІV , 1 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('З розбивкою на слова та відновленням втрачених фрагментів наявний текст ви- глядає таким чином : С(вѧ)тие м моу[ченикъ ] . Святі 40 мучеників . Датування .',
#   {'entities': [(144, 155, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 33 см , відстань від лівого кута 62 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Графіті № 4272 Розташування .',
#   {'entities': [(0, 9, 'inscription'), (15, 29, 'other')]}),
#  ('Висота від сучасної підлоги 45 см , відстань від лівого кута 35 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('А для надгробку використали мармурову деталь з собору , у якому він служив . Датування .',
#   {'entities': [(77, 88, 'dating_criteria')]}),
#  ('Висота від основи 118 см . Опис .',
#   {'entities': [(27, 33, 'inscription')]}),
#  ('Графіті № 437 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('На фресці прокреслений простий чотириконечний хрест . Датування .',
#   {'entities': [(10, 30, 'execution_technique'),
#     (31, 53, 'decoration'),
#     (54, 65, 'dating_criteria')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 719в ( табл .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('На фресці по вогкому тиньку прокреслений малюнок простого чотири- конечного хреста . Датування .',
#   {'entities': [(28, 57, 'decoration'), (85, 96, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Фреска втрачена також і в нижній частині .',
#   {'entities': [(0, 15, 'object_type')]}),
#  ('Висота від сучасної підлоги 80 см , відстань від лівого кута 398 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Опис .', {'entities': [(0, 6, 'inscription')]}),
#  ('Графіті № 4251 ( табл . ІХ , 2 )', {'entities': [(0, 9, 'inscription')]}),
#  ("Пам'ятний напис . Графіті № 4333 ( табл .",
#   {'entities': [(10, 17, 'inscription'), (18, 27, 'inscription')]}),
#  ('Молитовний напис . Графіті № 559 ( табл . LІ , 4 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Висота від сучасної підлоги 100 см , відстань від лівого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 56 см , відстань від правого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Поверхня стіни в місці розташування напису сильно пошкоджена ви- боями , тому тут простежуються тільки дві фрагментовані літери ДꙖ. Датування .',
#   {'entities': [(132, 143, 'dating_criteria')]}),
#  ('З розбивкою на слова текст виглядає таким чином : Г(оспод)и помози рабоу своемоу Михалови и ... Господи , поможи рабу своєму Михайлові та ... Рівна поверхня тиньку за останньою літерою свідчить , що графіті залишилось незавершеним . Датування .',
#   {'entities': [(199, 217, 'inscription'), (233, 244, 'dating_criteria')]}),
#  ("Напис практично повністю знищений вибоями , проте за його збереже- ними складовими можемо реконструювати виконане на фресці дієслово - звернення [ п]ом[ѧ]н[и ] ' пом'яни ' . Датування .",
#   {'entities': [(124, 146, 'other'), (174, 185, 'dating_criteria')]}),
#  ('Закінчення напису знищене обвалом тиньку , наявні три літери можна ре- конструювати як молитовне звернення Г(оспод)и п[омози',
#   {'entities': [(87, 116, 'inscription_type')]}),
#  ('На фресці прокреслена літера П. Датування .',
#   {'entities': [(32, 43, 'dating_criteria')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Графіті № 474 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('На поверхні стіни прокреслений простий чотириконечний хрест . Датування .',
#   {'entities': [(18, 38, 'execution_technique'),
#     (39, 61, 'decoration'),
#     (62, 73, 'dating_criteria')]}),
#  ('СХVІ , 3 ) Розташування .', {'entities': [(11, 25, 'other')]}),
#  ('Молитовний напис . Графіті № 554 ( табл .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Графіті № 692 ( табл . LХХХІІІ , 2 ) Розташування .',
#   {'entities': [(0, 9, 'inscription'), (37, 51, 'other')]}),
#  ('Складові напису сильно пошкоджені ерозією , тому не можуть бути впев- нено ідентифіковані . Датування .',
#   {'entities': [(92, 103, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 112 см , відстань від лівого кута 27 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Графіті № 436 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Молитовний напис . Графіті № 470 ( табл .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ("На фресці прокреслене слово рабъ ' раб ' . Датування .",
#   {'entities': [(43, 54, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 59 см , відстань від лівого кута 4 см . Опис .',
#   {'entities': [(68, 74, 'inscription')]}),
#  ("Пам'ятний напис . Графіті № 4338 ( табл . СХІ , 4 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (52, 66, 'other')]}),
#  ('На поверхні личкувального розчину прокреслений простий чотириконеч- ний хрест . Датування .',
#   {'entities': [(34, 54, 'execution_technique'),
#     (72, 79, 'decoration'),
#     (80, 91, 'dating_criteria')]}),
#  ("Пам'ятний напис . Графіті № 4334 ( табл .",
#   {'entities': [(10, 17, 'inscription'), (18, 27, 'inscription')]}),
#  ("Оскільки закінчення напису знищене обвалом тиньку , то встановити родове ім'я автора графіті не виявляється за можливе .",
#   {'entities': [(85, 95, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ("Пам'ятний напис . Графіті № 4332 ( табл .",
#   {'entities': [(10, 17, 'inscription'), (18, 27, 'inscription')]}),
#  ('Графіті № 665 ( табл . LХХVІІІ , 3 )',
#   {'entities': [(0, 9, 'inscription')]}),
#  ('Молитовний напис . Графіті № 533 ( табл . LХХV , 2 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (53, 67, 'other')]}),
#  ('Стародавній тиньк тут збе- рігся частково , на ньому виявлене одне графіті , якому надано номер 4280 ( табл . XVIII , 11 ) .',
#   {'entities': [(12, 21, 'material'), (67, 76, 'inscription')]}),
#  ('ХСV , 4 ) Розташування .', {'entities': [(10, 24, 'other')]}),
#  ('Висота від сучасної підлоги 129 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Висота від сучасної підлоги 91 см , відстань від лівого ребра 18 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('На той момент мармуровий карниз , який зберігся майже по всій північній стороні апсиди , був вкритий коричневою фарбою , нанесеної на нього , вочевидь , для імітації шиферного карнизу .',
#   {'entities': [(14, 33, 'object_type')]}),
#  ('Висота від сучасної підлоги 38,5 см , відстань від лівого кута 20 см . Опис .',
#   {'entities': [(71, 77, 'inscription')]}),
#  ('Графіті № 671 ( табл . LХХІХ , 3 ) Розташування .',
#   {'entities': [(0, 9, 'inscription'), (35, 49, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Графіті № 4360 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Графіті № 4271(табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Зважаючи на інформацію графіті № 4250 , на фресці наймовірніше був зоб- ражений св . Даниїл Стовпник .',
#   {'entities': [(23, 32, 'inscription')]}),
#  ('На фресці прокреслений простий чотириконечний хрест . Датування .',
#   {'entities': [(10, 30, 'execution_technique'),
#     (31, 53, 'decoration'),
#     (54, 65, 'dating_criteria')]}),
#  ('Графіті № 719 г ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Звертає на себе увагу помилкове подвійне написання р у передостанньому рядку . Датування .',
#   {'entities': [(79, 90, 'dating_criteria')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 115 см , відстань від лівого кута 65 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Висота від сучасної підлоги 19 см , відстань від лівого кута 44 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Висота від сучасної підлоги 96 см , відстань від лівого кута 56 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Графіті № 4246 ( табл . VІІІ , 2 ) Розташування .',
#   {'entities': [(0, 9, 'inscription'), (35, 49, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 107 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Висота від сучасної підлоги 49 см , відстань від правого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ("Початок та закінчення напису знищені вибоями , залишились тільки три літери від фрази [ помѧн]и ра[ба ] ' пом'яни раба ' . Датування .",
#   {'entities': [(123, 134, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 113 см , відстань від лівого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('На фресці прокреслена літера П. Датування .',
#   {'entities': [(32, 43, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Зображення ангелів та святих . Графіті № 552 ( табл .',
#   {'entities': [(31, 40, 'inscription')]}),
#  ('Найвірогідніше , що це ліва частина перекладини та па- гону проквітлого хреста . Датування .',
#   {'entities': [(81, 92, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 521 ( табл . LХХ , 2 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('На поверхні стіни простежується простий чотириконечний хрест . Датування .',
#   {'entities': [(40, 62, 'decoration'), (63, 74, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 110 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Четвертые чтения памяти Анны Мачинской , Старая Ладога , 21–23 декабря Датування .',
#   {'entities': [(71, 82, 'dating_criteria')]}),
#  ('Висота від нижнього краю зондажу 7 см , відстань від лівого краю зондажу 8,5 см . Опис .',
#   {'entities': [(82, 88, 'inscription')]}),
#  ('На фресці прокреслений малюнок шестикінечного хреста , що склада- ється зі щогли , перекладини та символічної таблички над головою Ісуса Христа .',
#   {'entities': [(10, 45, 'decoration')]}),
#  ('Графіті № 4314 ( табл . СVІ , 1 )', {'entities': [(0, 9, 'inscription')]}),
#  ('Сюжетні зображення . Графіті № 467 ( табл .',
#   {'entities': [(21, 30, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Графіті № 4264 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Висота від сучасної підлоги 83 см , відстань від лівого кута 521 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Молитовний напис . Графіті № 515 ( табл . LХVIІ , 1 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 112 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Висота від сучасної підлоги 49 см , відстань від правого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Висота від сучасної підлоги 123 см , відстань від правого ребра Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ('Опис На фресці прокреслений малюнок голуба . Датування .',
#   {'entities': [(0, 7, 'inscription'),
#     (15, 42, 'decoration'),
#     (45, 56, 'dating_criteria')]}),
#  ("На фресці прокреслене особове ім'я автора запису Федо\ue046 ' Федір ' та літера Ж – найвірогідніше , початок незавершеного або скороченого родового імені . Датування .",
#   {'entities': [(151, 162, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від основи 100 см . Опис .',
#   {'entities': [(27, 33, 'inscription')]}),
#  ('Графіті № 667 ( табл . LХХVІІІ , 5 ) Розташування .',
#   {'entities': [(0, 9, 'inscription'), (37, 51, 'other')]}),
#  ('Молитовний напис . Графіті № 41 ( табл . LVІІ , 2 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Молитовний напис . Графіті № 697 ( табл . LХХХІV , 2 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (55, 69, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Цим графіті надані порядкові номері від Графіті № 4281 ( табл .',
#   {'entities': [(4, 18, 'inscription'), (40, 49, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Фрагмент напису . Графіті № 4345 ( табл .',
#   {'entities': [(18, 27, 'inscription')]}),
#  ('Цитати та посилання на твори книжної писемності . і становлення української літератури , К. 1988 , с . 29–30 . Графіті № 74 ( табл . ХХVІІ , 2 ) Публікації .',
#   {'entities': [(111, 120, 'inscription')]}),
#  ('СІV , 1 ) Розташування .', {'entities': [(10, 24, 'other')]}),
#  ('Більша частина давнього мурування Софії Київської нині захована під пізнішим личкувальних розчином , вкритим побілкою , тож для вивчення наразі доступна тільки її частина , відкрита зондажами .',
#   {'entities': [(24, 39, 'object_type')]}),
#  ('На фресці прокреслений простий чотириконечний хрест . Датування .',
#   {'entities': [(10, 30, 'execution_technique'),
#     (31, 53, 'decoration'),
#     (54, 65, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Графіті № 4348 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ("Можливо , напис пов'язаний з іменами Євдокиї та Панкрата ( № 601 ) , що розташований вище .",
#   {'entities': [(10, 26, 'inscription')]}),
#  ('Запис лічби . Графіті № 447 ( табл .',
#   {'entities': [(14, 23, 'inscription')]}),
#  ("Напис сильно пошкоджений № 431 , так що від нього залишилось тільки особове ім'я Roman ' Роман ' та невиразні фрагменти родового імені . Датування .",
#   {'entities': [(137, 148, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ("Пам'ятний напис . Графіті № 4284 ( табл .",
#   {'entities': [(10, 17, 'inscription'), (18, 27, 'inscription')]}),
#  ('Молитовний напис . Графіті № 677 ( табл . LХХХ , 3 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (53, 67, 'other')]}),
#  ("Пам'ятний напис . Графіті № 700 ( табл . LХХХV , 2 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (53, 67, 'other')]}),
#  ('На фресці прокреслене людське обличчя : простежується овал голови та очі з бровами над ними . Датування .',
#   {'entities': [(94, 105, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 495 ( табл . LХ , 2 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (51, 65, 'other')]}),
#  ("На фресці простежується дієслово - звернення помоги ' поможи ' та щогла літери за нею , яка може інтерпретуватись як ініціал І або недописане ім'я автора . Датування .",
#   {'entities': [(24, 51, 'other'),
#     (66, 78, 'object_type'),
#     (156, 167, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 105,5 см , відстань від лівого кута Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ('Молитовний напис . Графіті № 582 ( табл . ХL , 2 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (51, 65, 'other')]}),
#  ('Молитовний напис . Графіті № 4295 ( табл . С ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (47, 61, 'other')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 97 см , відстань від лівого кута 340 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ("Пам'ятний напис . Графіті № 4247 ( табл . VІІІ , 3 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (53, 67, 'other')]}),
#  ('Тут був Симон ... Датування .',
#   {'entities': [(18, 29, 'dating_criteria')]}),
#  ('Графіті № 4248 ( табл . VІІІ , 4 ) Розташування .',
#   {'entities': [(0, 9, 'inscription'), (35, 49, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Висота від рівня давньої підлоги 182 см , відстань від лівого кута стіни 165,5 см . Опис .',
#   {'entities': [(84, 90, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 4303 ( табл . СІІІ , 2 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (54, 68, 'other')]}),
#  ('Висота від сучасної підлоги 132 см , відстань від лівого кута 65 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Графіті № 4270 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Від кінців перекладини над вершиною щогли прокреслене відкрите донизу півколо , на краях та посередині якого знаходяться чотириконечні хрестики54 . Датування .',
#   {'entities': [(148, 159, 'dating_criteria')]}),
#  ('Він походив з родини Горайнів або Гораймів ( герб Шренява)185 і був стольником Чернігова ( до 1673 р.)186 . Датування .',
#   {'entities': [(108, 119, 'dating_criteria')]}),
#  ('Запис лічби . Графіті № 4279 Розташування .',
#   {'entities': [(14, 23, 'inscription'), (29, 43, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Напис частково пошкоджений малюнком воїна ( № 4245 ) . Датування .',
#   {'entities': [(55, 66, 'dating_criteria')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 138 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Зображення ангелів та святих . Графіті № 615 ( табл . VІ , 4 ) Публікації .',
#   {'entities': [(31, 40, 'inscription')]}),
#  ('На фресці прокреслена літера Ꙁ. Датування .',
#   {'entities': [(32, 43, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Графіті № 672 ( табл . LХХІХ , 4 ) Розташування .',
#   {'entities': [(0, 9, 'inscription'), (35, 49, 'other')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('м(оу)ч(ени)кь молите за раба своего Георьгиѧ. Святі 40 мучеників , моліть за раба свого Георгія . Датування .',
#   {'entities': [(98, 109, 'dating_criteria')]}),
#  ('Напис знаходиться маже біля кута стіни , де в стовпчик було виконано кілька текстів , тому це графіті , яке збереглось порівняно з іншими краще , було відді- лено горизонтальними рисками зверху та знизу : преста | вис- | рабъ66бо67 | ж\ue01f\ue01fлазо | р68ъмцⷭ\ue003а',
#   {'entities': [(94, 103, 'inscription')]}),
#  ('Висота від сучасної підлоги 40 см , відстань від лівого кута 48 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ("Пам'ятний напис . Графіті № 4291 ( табл . ХСVІІІ , 4 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (55, 69, 'other')]}),
#  ("Пам'ятний напис . Графіті № 513 ( табл . LХVI , 1 ) Публікації .",
#   {'entities': [(10, 17, 'inscription'), (18, 27, 'inscription')]}),
#  ('Висота від рівня ґрунту 118 см , відстань від лівого кута стіни Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ('З розбивкою на слова та відновленням втрачених фрагментів наявний текст ви- глядає таким чином : ꙍ с(свѧ)ти [ м](оу)ч(е)н[ици ] мол[ите ] за [ мѧ ] ... О святі мученики , моліть за мене ... Датування .',
#   {'entities': [(190, 201, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 78 см , відстань від лівого кута 64 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 115 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Висота від рівня давньої підлоги 138 см , відстань від лівого кута стіни 5 см . Опис .',
#   {'entities': [(80, 86, 'inscription')]}),
#  ('Графіті № 549 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('ХС , 4 ) Розташування .', {'entities': [(9, 23, 'other')]}),
#  ('Тож Анна мала добру нагоду відвідати Софійський собор .',
#   {'entities': [(48, 55, 'monument')]}),
#  ('Фрагмент напису . Графіті № 4346 ( табл .',
#   {'entities': [(18, 27, 'inscription')]}),
#  ('Івана ... Датування .', {'entities': [(10, 21, 'dating_criteria')]}),
#  ('Неоднознач- ність в ідентифікації низки літер та їх суттєві пошкодження перешкоджають рекон- струкції тексту . Датування .',
#   {'entities': [(111, 122, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ("Пам'ятний напис . Графіті № 608 ( табл . ХХV , 2 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (51, 65, 'other')]}),
#  ('Висота від сучасної підлоги 125 см , відстань від лівого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Висота від сучасної підлоги 87 см , відстань від правого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Поверхня фрескового тиньку дуже крихка , тому тут наявна величезна кількість вибоїв та подряпин , які негативно вплинули на стан збереження графіті на цій ділянці , яких тут нараховуємо дванадцять .',
#   {'entities': [(140, 150, 'inscription')]}),
#  ('Тоді ж , у 2010 р . , Р. Гуцуля- ком були проведені аналізи розчинів з цієї частини собору , які й дозволили встановити приблизний вік побудови підпірного стовпа під аркбутан .',
#   {'entities': [(166, 176, 'object_type')]}),
#  ('Молитовний напис . Графіті № 563 ( табл . LІІ , 4 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Графіті № 535 ( табл . LХХV , 4 ) Розташування .',
#   {'entities': [(0, 9, 'inscription'), (34, 48, 'other')]}),
#  ('молю пом[илуи ] . Богородице , молю , помилуй . Датування .',
#   {'entities': [(48, 59, 'dating_criteria')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Графіті на північному фасаді Софійського собору Графіті № 4243 ( табл . ІІІ , 3 ) Розташування .',
#   {'entities': [(0, 10, 'inscription'),
#     (48, 57, 'inscription'),
#     (82, 96, 'other')]}),
#  ("своѥ[го ] ... Пом'яни , Господи , раба свого ... Датування .",
#   {'entities': [(49, 60, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Зважаючи на значні втрати , впевненій реконструкції підлягає тільки початок верхнього рядка напису : Рокꙋ ҂ ах͠не [ и]юнꙗ \ue027͠і днꙗ был т[ут ] ... Року 1655-го червня 19-го дня був тут ... Датування .',
#   {'entities': [(187, 198, 'dating_criteria')]}),
#  ('Ох , сороковиця , прости мене , Кузьму , ох . Датування .',
#   {'entities': [(46, 57, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 4306 ( табл .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Графіті № 4250 ( табл . ІХ , 1 ) Розташування .',
#   {'entities': [(0, 9, 'inscription'), (33, 47, 'other')]}),
#  ('На фресці прокреслені літери Г\ue002\ue01e та щогла літери П за ними , що є неза- вершеною формою традиційної формули Г(оспод)и',
#   {'entities': [(36, 48, 'object_type')]}),
#  ('Молитовний напис . Графіті № 494 ( табл . ХL , 1 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (51, 65, 'other')]}),
#  ('Графіті № 434 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Молитовний напис . Графіті № 517 ( табл . LХVIІ , 2 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('подальше вивчення прорізів довело , що ліва " щогла " щ є засічкою на язичку ѥ , а частина платформи є наслідком невдалої розчистки прорізів , тож на фресці чітко читаються ѥ та дзеркальна ц . Датування .',
#   {'entities': [(46, 53, 'object_type'), (193, 204, 'dating_criteria')]}),
#  ('Опис .', {'entities': [(0, 6, 'inscription')]}),
#  ("З розбивкою на слова текст виглядає таким чином : Помѥні раба П. Пом'яни раба П. Датування .",
#   {'entities': [(81, 92, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Святі 40 мучеників , моліть за раба свого Михайла . Датування .',
#   {'entities': [(52, 63, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 141 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Висота від основи 216 см . Опис .',
#   {'entities': [(27, 33, 'inscription')]}),
#  ("На фресці прокреслені літери ПОМ , які найвірогідніше розглядати як ско- рочену форму дієслова - звернення пом(ѧни ) ' пом'яни ' . Датування .",
#   {'entities': [(86, 114, 'other'), (131, 142, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 116 см , відстань від лівого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Знаходиться на північній стороні того ж виступу , що й згаданий вище напис ( табл . І ) .',
#   {'entities': [(69, 76, 'inscription')]}),
#  ('Молитовний напис . Графіті № 557 ( табл . LІ , 2 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('СV , 4 ) Розташування .', {'entities': [(9, 23, 'other')]}),
#  ('Тиньк в місці розташування дворядкового напису сильно пошкоджений вибоями , у верхньому рядку помітний склад ГА , у нижньому під ним – склад НА . Датування .',
#   {'entities': [(0, 7, 'material'), (146, 157, 'dating_criteria')]}),
#  ('Графіті № 590 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ("З розбивкою на слова та відновленням втраченого фрагмента текст виглядає таким чином : Помени м[ꙗ ] . Пом'яни мене . Датування .",
#   {'entities': [(117, 128, 'dating_criteria')]}),
#  ('Складові напису виконані доволі схематично , вони пошкоджені вибоями , тому впевнено можуть бути ідентифіковані тільки кілька з них – УГЛДВРВ у серед- ньому рядку , можливо ХЛ у верхньому та Б – в нижньому . Датування .',
#   {'entities': [(208, 219, 'dating_criteria')]}),
#  ('Тиньк в місці розташування напису пошкоджений , його закінчення зовсім не збереглось : г͠\ue01fпомо--',
#   {'entities': [(0, 7, 'material')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ("Поверхня стіни в місці розташування напису сильно пошкоджена , проте за наявними трьома літерами можемо реконструювати написане у три рядки ім'я зоб- раженого на фресці святого Ан\ue027[имос ] ' Анфім ' . Датування .",
#   {'entities': [(200, 211, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 56,5 см , відстань від лівого кута 36 см . Опис .',
#   {'entities': [(71, 77, 'inscription')]}),
#  ('Опис .', {'entities': [(0, 6, 'inscription')]}),
#  ('Молитовний напис . Графіті № 510 ( табл . LХV , 2 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (52, 66, 'other')]}),
#  ('Графіті № 669 ( табл . LХХІХ , 1 ) Розташування .',
#   {'entities': [(0, 9, 'inscription'), (35, 49, 'other')]}),
#  ('Молитовний напис . Графіті № 594 ( табл . ХLIV , 1 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (53, 67, 'other')]}),
#  ("Права частина напису знищена обвалом тиньку , проте наявні складові збереглись добре , текст відновлюється як фраза Г(оспод)и пом[ози ] ' Господи , поможи ' . Датування .",
#   {'entities': [(159, 170, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ("На фресці прокреслений літери ПОМ , що найвірогідніше реконструювати тут скорочену форму дієслова - прохання пом(ози ) ' поможи ' . Датування .",
#   {'entities': [(10, 29, 'execution_technique'),
#     (89, 116, 'other'),
#     (132, 143, 'dating_criteria')]}),
#  ("На фресці помітні виконані у стовпчик літери ПО та М\ue01e , які слід розгля- дати як незавершений або скорочений запис дієслова - прохання поми{лоуи } ' помилуй ' . Датування .",
#   {'entities': [(109, 144, 'inscripiton type'),
#     (161, 172, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ("Пом'яни , Господи , раба ... Датування .",
#   {'entities': [(29, 40, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 4302 ( табл . СІІІ , 1 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (54, 68, 'other')]}),
#  ("Початок та закінчення напису не збереглись , простежується тільки се- редня його частина , яка реконструюється як слово - звернення [ Гос]под[и ] ' Господи ' .",
#   {'entities': [(114, 133, 'other')]}),
#  ('На фресці прокреслений простий чотириконечний хрест . Датування .',
#   {'entities': [(10, 30, 'execution_technique'),
#     (31, 53, 'decoration'),
#     (54, 65, 'dating_criteria')]}),
#  ('У верхньому рядку простежуються літера \ue01e , у нижньому – \ue01eВЪ . Датування .',
#   {'entities': [(62, 73, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 58 см , відстань від лівого кута 68 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Графіті № 682 ( табл . LХХХІ , 3 ) Розташування .',
#   {'entities': [(0, 9, 'inscription'), (35, 49, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('На фресці виконане молитовне звернення : Помени Марка .',
#   {'entities': [(19, 40, 'inscription_type')]}),
#  ('На фресці прокреслений чотириконечний хрест , кінці якого розширю- ються у вигляді лілій . Датування .',
#   {'entities': [(10, 22, 'execution_technique'),
#     (23, 45, 'decoration'),
#     (91, 102, 'dating_criteria')]}),
#  ('Висота від основи 203 см . Опис .',
#   {'entities': [(27, 33, 'inscription')]}),
#  ('За останньою літерою помітна щогла ще однієї незакінченої , що свідчить про не- завершеність напису , зверненого до зображених на фресці святих .',
#   {'entities': [(29, 37, 'object_type')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ("Пам'ятний напис . Графіті № 4315 ( табл . СVІ , 2 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (52, 66, 'other')]}),
#  ('Висота від сучасної підлоги 87,5 см , відстань від лівого кута Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Графіті № 573 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Висота від сучасної підлоги 83,5 см , відстань від правого кута Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ('Висота від сучасної підлоги 48 см , відстань від лівого кута 67 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 105 см , відстань від правого ребра Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ('Доволі великий напис , витягнутий в один рядок , зберігся доволі добре , його складові чітко читаються : гипоⷨзирабусвоемуⷪпетрухромомуⷪмисативседоброе',
#   {'entities': [(15, 22, 'inscription')]}),
#  ('Окрім вже опублікованого графіті , на карнизі виявлено ще два написи , які отримали порядкові номери 2030а та 2030б .',
#   {'entities': [(25, 34, 'inscription')]}),
#  ('Окрім самого тіла колони поруч експонується її мармурова база , у верхній частині якої поставлена робоча по- значка у вигляді літери Y ( табл . ХІ , 3 ) .',
#   {'entities': [(47, 63, 'object_type')]}),
#  ('Незважаючи на пошкодження тиньку , напис зберігся доволі добре : тꙋтъ быⷧ\ue003 раⷠ',
#   {'entities': [(35, 49, 'inscription')]}),
#  ('Висота від сучасної підлоги 116 см , відстань від лівого кута 64 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('На фресці прокреслені літери П\ue000 Д\ue000 Р\ue000 Ф\ue000. Датування .',
#   {'entities': [(42, 53, 'dating_criteria')]}),
#  ("Вплив цієї традиції на київську ( софійську ) писемну школу слід пов'язувати з перебуванням свити митрополита Кипріана31 , який з березня 1396 р . близько півтора року знаходився у Києві32 . Датування .",
#   {'entities': [(191, 202, 'dating_criteria')]}),
#  ("ГРАФІТІ НА МАРМУРОВИХ КОЛОНАХ У НАРТЕКСІ СОФІЙСЬКОГО СОБОРУ Цей розділ присвячений публікації епіграфічних пам'яток , що знаходяться на поверхні двох мармурових колон , які нині експонуються у нартексі Софії Київської під східною стіною обабіч входу до храму .",
#   {'entities': [(0, 10, 'inscription')]}),
#  ('Висота від сучасної підлоги 92 см , відстань від лівого кута 75 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('На фресці прокреслений простий чотириконечний хрест . Датування .',
#   {'entities': [(10, 30, 'execution_technique'),
#     (31, 53, 'decoration'),
#     (54, 65, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 4359 ( табл .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Висота від сучасної підлоги 86 см , відстань від лівого кута 56 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Молитовний напис . Графіті № 564 ( табл . LІІ , 5 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Висота від сучасної підлоги 89,5 см , відстань від лівого ребра Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ('Висота від сучасної підлоги 78,5 см , відстань від лівого ребра Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ('Проте не виключено й те , що напис виник як своєрідне прохання успішної місії по- сланців князя Святополка ІІ до Володимира Мономаха – княгині Всеволодової , дру- жини померлого та похованого у Софійському соборі у 1093 р . Всеволода Ярославича , та київського митрополита Миколая , які мали примирити ворогуючих князів та при- пинити міжусобицю , що виникла внаслідок осліплення Василька184 .',
#   {'entities': [(29, 40, 'inscription')]}),
#  ('Графіті № 572 ( табл . LІV , 5 ) Публікації .',
#   {'entities': [(0, 9, 'inscription')]}),
#  ('Фрагмент напису . Графіті № 4289 ( табл .',
#   {'entities': [(18, 27, 'inscription')]}),
#  ('Висота від сучасної підлоги 78 см , відстань від правого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Молитовний напис . Графіті № 312 ( табл . LХІ , 1 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Опис .', {'entities': [(0, 6, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Графіті № 4309 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Молитовний напис . Графіті № 717 ( табл .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Графіті № 684 ( табл . LХХХІ , 5 ) Розташування .',
#   {'entities': [(0, 9, 'inscription'), (35, 49, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('СІ , 2 ) Розташування .', {'entities': [(9, 23, 'other')]}),
#  ('Мученики , дайте мені милість Божу від мук вогняних і від пекельних ... Датування .',
#   {'entities': [(72, 83, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 497 ( табл . LХІІ , 1 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (53, 67, 'other')]}),
#  ('Молитовний напис . Графіті № 152 ( табл . ХХІХ , 1 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Висота від сучасної підлоги 43 см , відстань від правого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ("На поверхні фрески простежуються літери САМО , які , можливо , варто роз- глядати як незавершений запис імені Само{уилъ } ' Самуїл ' . Датування .",
#   {'entities': [(98, 109, 'inscription'), (135, 146, 'dating_criteria')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 71 см , відстань від лівого кута 3,5 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('На поверхні личкувального розчину прокреслений простий чотириконеч- ний хрест . Датування .',
#   {'entities': [(34, 54, 'execution_technique'),
#     (72, 79, 'decoration'),
#     (80, 91, 'dating_criteria')]}),
#  ("Пам'ятний напис . Графіті № 707 ( табл . LХХХVIІ , 3 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (55, 69, 'other')]}),
#  ('Графіті № 581 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Висота від сучасної підлоги 87 см , відстань від лівого кута 11,5 см . Опис .',
#   {'entities': [(71, 77, 'inscription')]}),
#  ('Висота від сучасної підлоги 68,5 см , відстань від правого ребра Опис .',
#   {'entities': [(65, 71, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 153 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Права частина пошкоджена вибоєм , проте за наявними фрагментами мо- жемо встановити , що тут була прокреслена літера М. Датування .',
#   {'entities': [(120, 131, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 505 ( табл . LХІІІ , 2 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (54, 68, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Наприкінці ХІ ст. під аркбутан , як і у ви- падку з північною стороною відкритої зовнішньої галереї , був зведений підпірний стовп , який закрив собою первісну фреску .',
#   {'entities': [(22, 32, 'object_type'), (115, 132, 'object_type')]}),
#  ('Висота від сучасної підлоги 57 см , відстань від лівого кута 21 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('На фресці прокреслений знак у вигляді цифри 8 . Датування .',
#   {'entities': [(10, 27, 'execution_technique'),
#     (48, 59, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 4356 ( табл .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Графіті № 4290 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('За нею тиньк пошкоджений , тож тут , найвірогідніше , могли знаходитись й інші літери .',
#   {'entities': [(7, 24, 'material')]}),
#  ('Графіті на мармуровій колоні у північній частині нартексу Мармурова колона довжиною близько 3,5 м , що нині експонується в північній частині нартексу ( табл . ХІ , 1 ) , розбита на дві частини .',
#   {'entities': [(0, 10, 'inscription'), (58, 83, 'object_type')]}),
#  ('Опис На фресці прокреслені літери ВО . Датування .',
#   {'entities': [(0, 7, 'inscription'), (39, 50, 'dating_criteria')]}),
#  ('Вочевидь , напис лишився не- завершеним . Датування .',
#   {'entities': [(11, 24, 'inscription'), (42, 53, 'dating_criteria')]}),
#  ('Графіті № 4263 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Висота від сучасної підлоги 110 см , відстань від правого ребра Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ('Тим не менше , його збережені складові ідентифікуються добре , а сам текст піддається повній реконструкції : С[т]еф / а / ань Иван[овичь ] . Стефан Іванович . Датування .',
#   {'entities': [(159, 170, 'dating_criteria')]}),
#  ('Фрагмент напису . Графіті № 4336 ( табл .',
#   {'entities': [(18, 27, 'inscription')]}),
#  ("На фресці прокреслене дієслово - прохання помꙗни ' помяни ' . Датування .",
#   {'entities': [(22, 48, 'other'), (62, 73, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Молитовний напис . Графіті № 518 ( табл . LХІХ , 1 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('На фресці прокреслені літери NW . Датування .',
#   {'entities': [(34, 45, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 64 см , відстань від лівого кута 41,5 см . Опис .',
#   {'entities': [(71, 77, 'inscription')]}),
#  ("Пам'ятний напис . Графіті № 705 ( табл . LХХХVIІ , 1 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (55, 69, 'other')]}),
#  ('Висота від сучасної підлоги 106 см , відстань від правого ребра Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ("Образ святого ідентифікується завдяки двом написам - графіті , які повідомляють його ім'я ( № 432 та № 433)49 .",
#   {'entities': [(53, 62, 'inscription')]}),
#  ("На фресці прокреслені літери Г\ue002\ue01e , що є традиційним скороченням слова- звернення Г(оспод)[и ] ' Господи ' . Датування .",
#   {'entities': [(108, 119, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 702 ( табл . LХХХVІ , 1 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (55, 69, 'other')]}),
#  ('На поверхні мармурової колони прокреслені літери Н\ue01e. Датування .',
#   {'entities': [(53, 64, 'dating_criteria')]}),
#  ('Фрагмент напису . Графіті № 4293 ( табл .',
#   {'entities': [(18, 27, 'inscription')]}),
#  ('Напис практично повністю знищений вибоєм , залишилась тільки частина літери У. Датування .',
#   {'entities': [(79, 90, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 69 см , відстань від лівого ребра 7 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Висота від основи 117 см . Опис .',
#   {'entities': [(27, 33, 'inscription')]}),
#  ('Висота від сучасної підлоги 131 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Висота від сучасної підлоги 107 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ("Зважаючи на наявність титла та вибоїну перед першою літерою , текст найвірогідніше реконструювати як запис імені [ І]ꙍа(нъ ) ' Йоанн ' . Датування .",
#   {'entities': [(101, 112, 'inscription'), (137, 148, 'dating_criteria')]}),
#  ('Графіті на фресці з зображенням орнаменту Фреска розташована у північно - східному куті хрещальні , на південній грані за- хідної лопатки виступу стіни .',
#   {'entities': [(0, 10, 'inscription'), (42, 60, 'object_type')]}),
#  ("Найвірогідніше реконструювати текст як ім'я Ла[рионъ ] ' Іларіон ' . Датування .",
#   {'entities': [(69, 80, 'dating_criteria')]}),
#  ('На фресці прокреслений простий чотириконечний хрест . Датування .',
#   {'entities': [(10, 30, 'execution_technique'),
#     (31, 53, 'decoration'),
#     (54, 65, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 96,5 см , відстань від лівого кута Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 266 см , відстань від лівого ребра стіни 24 см . Опис .',
#   {'entities': [(77, 83, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('СХІІІ , 4 ) Розташування .', {'entities': [(12, 26, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ("На фресці тим же автором прокреслені літери РА , вочевидь , незавершене слово ра{бъ } ' раб ' . Датування .",
#   {'entities': [(96, 107, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 71 см , відстань від лівого кута 32 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Графіті на фресці з зображенням Сорока мучеників Севастійських Фреска розташована на південній стіні хрещальні , сюжет впевнено визнача- ється завдяки іконографії та численним написам - графіті , що називають зображених тут святих .',
#   {'entities': [(0, 10, 'inscription'),
#     (63, 81, 'object_type'),
#     (186, 195, 'inscription')]}),
#  ('Знаходиться на північній стіні між двома її середніми висту- пами у невеликому зондажі давнього мурування ( табл . І ) .',
#   {'entities': [(96, 107, 'object_type')]}),
#  ('Висота від основи 102 см . Опис .',
#   {'entities': [(27, 33, 'inscription')]}),
#  ('Висота від сучасної підлоги 72 см , відстань від лівого кута 45 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Окрім них , виявлено ще більше сотні графіті № № 495 – ( табл .',
#   {'entities': [(37, 46, 'inscription')]}),
#  ('Графіті № 492 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Молитовний напис . Графіті № 606 ( табл .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Фрагмент напису . Графіті № 4294 ( табл .',
#   {'entities': [(18, 27, 'inscription')]}),
#  ('На фресці подвійними рисками прокреслений малюнок чотириконечного хреста , у правій частині перекладини якого намічене декорування у вигляді ламаної лінії . Датування .',
#   {'entities': [(29, 65, 'decoration'), (157, 168, 'dating_criteria')]}),
#  ('Графіті № 4325 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('На поверхні стіни прокреслена літера Σ. Датування .',
#   {'entities': [(40, 51, 'dating_criteria')]}),
#  ('Графіті № 504 ( табл . LХІІІ , 1 ) Розташування .',
#   {'entities': [(0, 9, 'inscription'), (35, 49, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від сучасної підлоги 92 см , відстань від лівого кута 107 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
# ...
#   {'entities': [(62, 68, 'inscription')]}),
#  ('На мій погляд , більш вірогідно віднести верхню межу часу мож- ливої появи графіті на колоні до початку XVII ст. Графіті № 4253 ( табл .',
#   {'entities': [(75, 85, 'inscription'), (113, 122, 'inscription')]}),
#  ('Висота від сучасної підлоги 60,5 см , відстань від лівого кута Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ("Пам'ятний напис . Графіті № 265 ( табл . ХХVІІІ , 2 ) Публікації .",
#   {'entities': [(10, 17, 'inscription'), (18, 27, 'inscription')]}),
#  ('Графіті № 2030а ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Молитовний напис . Графіті № 619 ( табл . LХХVІ , 3 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (54, 68, 'other')]}),
#  ('На фресці прокреслені літери ИИИИ . Датування .',
#   {'entities': [(36, 47, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 4316 ( табл . СVІ , 3 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (53, 67, 'other')]}),
#  ("Висоцький пов'язував напис з малюнком , що розглядався вище , проте , на мою думку , доцільніше пов'язати текст з символічним описом подвигу Сорока Се- вастійських мучеників , зображених у хрещальні на північній стіні .",
#   {'entities': [(21, 28, 'inscription')]}),
#  ('Запис лічби . Графіті № 4276 Розташування .',
#   {'entities': [(14, 23, 'inscription'), (29, 43, 'other')]}),
#  ('Висота від основи 209 см . Опис .',
#   {'entities': [(27, 33, 'inscription')]}),
#  ('Молитовний напис . Графіті № 522 ( табл . LХХІ , 1 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ("Розташування та ступінь ерозії прорізів дозволяє встановити , що шість з них ( № № 4262–4267 ) з'явились у той час , коли колона перебувала у верти- кальному положенні , найімовірніше , до початку XVII ст. ; два ( № 4269 та № 4270 ) – коли колона вже лежала , тобто , десь до межі XVII – XVIII ст. ; а одне ( № 4268 ) – на- несене правильно по відношенню до вертикального положення колони , проте ступінь ерозії прорізів ( а також палеографія ) вказує , що невдовзі після нанесення напису колона деякий час перебувала на софійському подвір'ї , а згодом була присипана землею .",
#   {'entities': [(0, 15, 'other'),
#     (122, 139, 'object_type'),
#     (240, 250, 'object_type'),
#     (431, 444, 'dating_criteria'),
#     (489, 502, 'object_type')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Графіті з зображенням орнаменту Фреска розташована на південному схилі невеликої арки , закритої нині фанер- ним щитом , а в давнину наскрізної , що сполучала апсиду хрещальні та західну внут- рішню галерею Софійського собору .',
#   {'entities': [(0, 9, 'inscription'), (32, 50, 'object_type')]}),
#  ('Висота від сучасної підлоги 80 см , відстань від лівого кута 42 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Молитовний напис . Графіті № 516 ( табл . LХVIIІ , 1 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('На фресці прокреслений простий чотириконечний хрест . Датування .',
#   {'entities': [(10, 30, 'execution_technique'),
#     (31, 53, 'decoration'),
#     (54, 65, 'dating_criteria')]}),
#  ('Вочевидь , під час будівництва апсиди фреска була пошкоджена та від- ремонтована , або майстри відбили тут тиньк , який погано тримався .',
#   {'entities': [(38, 49, 'object_type'), (107, 114, 'material')]}),
#  ('Молитовний напис . Графіті № 612 ( табл . VІ , 1 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Трирядковий запис обчислення кількості проведених поминальних служб .',
#   {'entities': [(12, 49, 'inscription_type')]}),
#  ('Графіті № 438 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Молитовний напис . Графіті № 621 ( табл . LХХVІІ , 1 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (55, 69, 'other')]}),
#  ("Молитовний напис . тектурного об'єму ; 2 – розташування давнього мурування у хрещальні ( за Н. Нікі- тенко ): а – первісне мурування ХІ ст. ; б – мурування підпірного під аркбутан стовпа ХІ ст. ; в – мурування апсиди ХІІ ст. ; г – давні ( ХІ ст. ) пройми арок галереї , закла- дені під час пізніших перебудов Схема хрещальні Софійського собору з позначенням місця розташування графіті та дипінті : 1 – на західній стороні північного виступу стіни , № № 4272–4279 ; 2 – на фресці з зображенням орнаменту , № № 484–493 , 601–608 ; 3 – на фресці з зобра- женням св . Марка , № № 14 , 72–74 , 147 , 152 , 265 , 430–443 , 445–449 , 467–480 , 494 , лотустого , № № 4281–4310 ; 5 – на фресці зображенням орнаменту , № 4311 ; 6 – на фресці з зображенням невідомих святителів , № № 4312–4347 ; 7 – на фресці з зоб- раженням невідомого святого , № № 4348–4359 ; 8 – на фресці з зображенням орна- менту , № 4360 ; 9 – на фресці з зображенням св . Анфіма , № № 481–482 , 498–501 , фресці з зображенням орнаменту , № 4280 .",
#   {'entities': [(11, 18, 'inscription'),
#     (65, 76, 'object_type'),
#     (123, 135, 'object_type'),
#     (146, 166, 'object_type'),
#     (171, 186, 'object_type'),
#     (200, 220, 'object_type'),
#     (377, 387, 'inscription')]}),
#  ('Через значні втрати реконструкція тексту неможлива . Датування .',
#   {'entities': [(53, 64, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 480 ( табл . ХХХІХ , 3 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (54, 68, 'other')]}),
#  ("На фресці прокреслене дієслово - прохання помени ' пом'яни ' . Датування .",
#   {'entities': [(22, 48, 'other'), (63, 74, 'dating_criteria')]}),
#  ('Висота від рівня давньої підлоги 175 см , відстань від лі- вого кута стіни 116 см . Опис .',
#   {'entities': [(84, 90, 'inscription')]}),
#  ("Пам'ятний напис . Графіті № 711 ( табл . LХХХІХ , 2 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (54, 68, 'other')]}),
#  ("Особове ім'я збереглось добре , воно чітко читається як Мартин ' Мартин ' . Датування .",
#   {'entities': [(76, 87, 'dating_criteria')]}),
#  ('Господи , поможи рабу своєму Луці . Датування .',
#   {'entities': [(36, 47, 'dating_criteria')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 60 см , відстань від правого ребра Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Молитовний напис . Графіті № 678 ( табл . LХХХ , 4 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (53, 67, 'other')]}),
#  ('Висота від сучасної підлоги 96 см , відстань від лівого кута 113 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Висота від основи 110 см . Опис .',
#   {'entities': [(27, 33, 'inscription')]}),
#  ('Графіті № 476 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('На фресці прокреслений квадрат з крапкою посередині . Датування .',
#   {'entities': [(10, 30, 'execution_technique'),
#     (54, 65, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Святі 40 мучеників , помилуйте . Датування .',
#   {'entities': [(33, 44, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Графіті № 592 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('На фресці прокреслений чотириконечний хрест з розширеними у вигляді заглиблених крапок кінцями . Датування .',
#   {'entities': [(10, 22, 'execution_technique'),
#     (23, 45, 'decoration'),
#     (97, 108, 'dating_criteria')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('ХХХІ , 2 ) Розташування .', {'entities': [(11, 25, 'other')]}),
#  ('Молитовний напис . Графіті № 479 ( табл .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('На фресці прокреслений восьмикінечний хрест , що складається зі щогли , перекладини , символічної таблички над головою Ісуса Христа та горизонтального підніжжя .',
#   {'entities': [(10, 37, 'execution_technique'), (38, 45, 'decoration')]}),
#  ('Закінчення напису не збереглось внаслідок обвалу тиньку , проте наявні складові дозволяють без труднощів прочитати напис : поменим-',
#   {'entities': [(115, 122, 'inscription')]}),
#  ('Молитовний напис . Графіті № 553 ( табл . L , 1 ) Публікації .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ("{ помози } ' Господи , поможи ' . Датування .",
#   {'entities': [(34, 45, 'dating_criteria')]}),
#  ('Підпис до фрескового образу . Графіті № 569 ( табл . LІІІ , 3 ) Публікації .',
#   {'entities': [(30, 39, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ("Пам'ятний напис . Графіті № 4352 ( табл . СХV , 1 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (52, 66, 'other')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Графіті на східному фасаді Софійського собору Графіті № 4244 ( табл . ІІІ , 4 ) Розташування .',
#   {'entities': [(0, 10, 'inscription'),
#     (46, 55, 'inscription'),
#     (80, 94, 'other')]}),
#  ('Графіті № 439 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ('Святих 40 мучеників . Датування .',
#   {'entities': [(22, 33, 'dating_criteria')]}),
#  ("На фресці прокреслені літери Г\ue01e , що є традиційним скороченням слова- звернення Г(оспод)[и ] ' Господи ' . Датування .",
#   {'entities': [(107, 118, 'dating_criteria')]}),
#  ('Загалом же збереженість напису добра , його складові чітко читаються : ст͠\ue01f:м҃-мнⷱ\ue003къмол\ue01fт - б͠азаме | негрѣшънаго\ue01fоана',
#   {'entities': [(11, 36, 'preservation_state')]}),
#  ('Висота від сучасної підлоги 30,5 см , відстань від лівого кута 56 см . Опис .',
#   {'entities': [(71, 77, 'inscription')]}),
#  ('Висота від сучасної підлоги 71 см , відстань від лівого кута 49 см . Опис .',
#   {'entities': [(69, 75, 'inscription')]}),
#  ('Висота від сучасної підлоги 107 см , відстань від правого ребра Опис .',
#   {'entities': [(64, 70, 'inscription')]}),
#  ("Пам'ятний напис . Графіті № 4310 ( табл .",
#   {'entities': [(10, 17, 'inscription'), (18, 27, 'inscription')]}),
#  ('Молитовний напис . Графіті № 604 ( табл .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('На фресці прокреслений стилізований малюнок листка . Датування .',
#   {'entities': [(10, 35, 'execution_technique'),
#     (53, 64, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 82 см , відстань від лівого кута 161 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Молитовний напис . Графіті № 4340 ( табл .',
#   {'entities': [(11, 18, 'inscription'), (19, 28, 'inscription')]}),
#  ('Нині – с . Новосілки Макарівського району Київської області . Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('СV , 5 ) Розташування .', {'entities': [(9, 23, 'other')]}),
#  ('Фрагмент напису . Графіті № 4328 ( табл . СVІІІ , 6 ) Розташування .',
#   {'entities': [(18, 27, 'inscription'), (54, 68, 'other')]}),
#  ('На фресці помітна невеличка літера Р , яка є єдиною складовою напису . Датування .',
#   {'entities': [(71, 82, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 111 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Зважаючи на колективний характер молитовного звернення та вживання у тексті тільки особових імен авторів , доцільно припустити , що у тексті згадуються ченці , які відвідали Святу Софію . Датування .',
#   {'entities': [(188, 199, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 676 ( табл . LХХХ , 2 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (53, 67, 'other')]}),
#  ('16[3]4 и[юнѧ ] ... Григорій ... , 1634-го , червня ... Датування .',
#   {'entities': [(55, 66, 'dating_criteria')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Окрім самого тіла колони поруч експонується її мармурова база , у верхній частині якої поставлена робоча позначка у вигляді літери П ( табл . ХІ , 5 ) .',
#   {'entities': [(47, 63, 'object_type')]}),
#  ('Схожий малюнок хреста вже зустрічався серед графіті Софійського собору , його публікував С.',
#   {'entities': [(44, 63, 'inscription')]}),
#  ('На фресці прокреслений шестикінечний хрест , що складається зі щогли , перекладини та символічної таблички над головою Ісуса Христа .',
#   {'entities': [(10, 36, 'execution_technique'), (37, 44, 'decoration')]}),
#  ('Висота від сучасної підлоги 113 см , відстань від лівого кута 46 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('На фресці прокреслені літери Л\ue002В. Датування .',
#   {'entities': [(34, 45, 'dating_criteria')]}),
#  ('ХLI , 3 ) Розташування .', {'entities': [(10, 24, 'other')]}),
#  ('Висота від сучасної підлоги 75 см , відстань від лівого кута 9 см . Опис .',
#   {'entities': [(68, 74, 'inscription')]}),
#  ('Графіті № 611 ( табл . VІ , 2 ) Публікації .',
#   {'entities': [(0, 9, 'inscription')]}),
#  ("Пам'ятний напис . Графіті № 696 ( табл . LХХХІV , 1 ) Розташування .",
#   {'entities': [(10, 17, 'inscription'),
#     (18, 27, 'inscription'),
#     (54, 68, 'other')]}),
#  ('Розташування .', {'entities': [(0, 14, 'other')]}),
#  ("Тобто , тут знаходиться незавершена тради- ційна молитовна формула Г(оспод)и по{мози } ' Господи , поможи ' . Датування .",
#   {'entities': [(49, 76, 'other'), (110, 121, 'dating_criteria')]}),
#  ('Висота від сучасної підлоги 46 см , відстань від правого кута 19 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Датування .', {'entities': [(0, 11, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 680 ( табл . LХХХІ , 1 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (54, 68, 'other')]}),
#  ('Графіті № 4323 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Висота від сучасної підлоги 135 см , відстань від лівого кута Опис .',
#   {'entities': [(62, 68, 'inscription')]}),
#  ('Висота від сучасної підлоги 36 см , відстань від правого кута 12 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Висота від сучасної підлоги 95,5 см , відстань від лівого кута Опис .',
#   {'entities': [(63, 69, 'inscription')]}),
#  ('Графіті № 73 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Н. Сінкевич та В. Корнієнко75 . Розташування .',
#   {'entities': [(32, 46, 'other')]}),
#  ('Тож вірогідніше , що колона походить все ж з Софійського собору .',
#   {'entities': [(21, 36, 'object_type')]}),
#  ("Розташування та ступінь ерозії прорізів дозволяє встановити , що графіті наносили у той час , коли колона перебувала у вертикальному положенні , найімовірніше , до початку XVII ст. ( якщо вона знахо- дилась біля західного порталу , що зруйнувався у цей час ) , або до межі XVII – XVIII ст. , коли масштабні будівельні роботи змінили зовнішній вигляд храму і колони були забрані та перебували на софійському подвір'ї , допоки не були присипані землею до їх виявлення у 1838 р .",
#   {'entities': [(0, 15, 'other'),
#     (65, 81, 'inscription'),
#     (99, 116, 'object_type')]}),
#  ('Фрагмент напису . Графіті № 4347 ( табл .',
#   {'entities': [(18, 27, 'inscription')]}),
#  ('Графіті № 493 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Висота від сучасної підлоги 107 см , відстань від лівого кута 65 см . Опис .',
#   {'entities': [(70, 76, 'inscription')]}),
#  ('Відтак , означене графіті пояснює сенс зображеного на фресці . Датування .',
#   {'entities': [(18, 33, 'inscription'), (63, 74, 'dating_criteria')]}),
#  ('Молитовний напис . Графіті № 693 ( табл . LХХХІІІ , 3 ) Розташування .',
#   {'entities': [(11, 18, 'inscription'),
#     (19, 28, 'inscription'),
#     (56, 70, 'other')]}),
#  ('Графіті № 4286 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ('Графіті № 595 ( табл .', {'entities': [(0, 9, 'inscription')]}),
#  ...]

# %% [markdown]
# # Prepare SpaCy NER model

# %%
import spacy
from spacy.training import Example

# https://towardsdatascience.com/train-ner-with-custom-training-data-using-spacy-525ce748fab7

# Load a blank model or a pre-existing model for your language
nlp = spacy.blank('uk')  # Replace 'en' with your language code if different

# Create the NER component if it doesn't exist
if 'ner' not in nlp.pipe_names:
    ner = nlp.add_pipe('ner')
else:
    ner = nlp.get_pipe('ner')

# Add labels
for _, annotations in train_data:
    for ent in annotations.get('entities'):
        ner.add_label(ent[2])

# %% [markdown]
# # Train a SpaCy NER model

# %%
from spacy.util import minibatch, compounding

optimizer = nlp.initialize()

# Use the training data
for epoch in range(25):
    random.shuffle(train_data)
    losses = {}
    batches = minibatch(train_data, size=compounding(4., 32., 1.001))
    for batch in batches:
        for text, annotations in batch:
            doc = nlp.make_doc(text)
            example = Example.from_dict(doc, annotations)
            nlp.update([example], drop=0.5, sgd=optimizer, losses=losses)
    print(f"Losses at epoch {epoch}: {losses}")
# Out:
# Losses at epoch 0: {'ner': 1122.94405920648}
# Losses at epoch 1: {'ner': 527.1068041042239}
# Losses at epoch 2: {'ner': 537.4914999522258}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 14
#      12         doc = nlp.make_doc(text)
#      13         example = Example.from_dict(doc, annotations)
# ---> 14         nlp.update([example], drop=0.5, sgd=optimizer, losses=losses)
#      15 print(f"Losses at epoch {epoch}: {losses}")
#
# File ~/Library/Python/3.9/lib/python/site-packages/spacy/language.py:1155, in Language.update(self, examples, _, drop, sgd, losses, component_cfg, exclude, annotates)
#    1152 for name, proc in self.pipeline:
#    1153     # ignore statements are used here because mypy ignores hasattr
#    1154     if name not in exclude and hasattr(proc, "update"):
# -> 1155         proc.update(examples, sgd=None, losses=losses, **component_cfg[name])  # type: ignore
#    1156     if sgd not in (None, False):
#    1157         if (
#    1158             name not in exclude
#    1159             and isinstance(proc, ty.TrainableComponent)
#    1160             and proc.is_trainable
#    1161             and proc.model not in (True, False, None)
#    1162         ):
#
# File ~/Library/Python/3.9/lib/python/site-packages/spacy/pipeline/transition_parser.pyx:405, in spacy.pipeline.transition_parser.Parser.update()
#
# File ~/Library/Python/3.9/lib/python/site-packages/thinc/model.py:309, in Model.begin_update(self, X)
#     302 def begin_update(self, X: InT) -> Tuple[OutT, Callable[[OutT], InT]]:
#     303     """Run the model over a batch of data, returning the output and a
#     304     callback to complete the backward pass. A tuple (Y, finish_update),
#     305     where Y is a batch of output data, and finish_update is a callback that
#     306     takes the gradient with respect to the output and an optimizer function,
#     307     and returns the gradient with respect to the input.
#     308     """
# --> 309     return self._func(self, X, is_train=True)
#
# File ~/Library/Python/3.9/lib/python/site-packages/spacy/ml/tb_framework.py:33, in forward(model, X, is_train)
#      32 def forward(model, X, is_train):
# ---> 33     step_model = ParserStepModel(
#      34         X,
#      35         model.layers,
#      36         unseen_classes=model.attrs["unseen_classes"],
#      37         train=is_train,
#      38         has_upper=model.attrs["has_upper"],
#      39     )
#      41     return step_model, step_model.finish_steps
#
# File ~/Library/Python/3.9/lib/python/site-packages/spacy/ml/parser_model.pyx:213, in spacy.ml.parser_model.ParserStepModel.__init__()
#
# File ~/Library/Python/3.9/lib/python/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/Library/Python/3.9/lib/python/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/Library/Python/3.9/lib/python/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/Library/Python/3.9/lib/python/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/Library/Python/3.9/lib/python/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/Library/Python/3.9/lib/python/site-packages/thinc/layers/with_array.py:43, in forward(model, Xseq, is_train)
#      41     return model.layers[0](Xseq, is_train)
#      42 else:
# ---> 43     return cast(Tuple[SeqT, Callable], _list_forward(model, Xseq, is_train))
#
# File ~/Library/Python/3.9/lib/python/site-packages/thinc/layers/with_array.py:78, in _list_forward(model, Xs, is_train)
#      76 lengths = NUMPY_OPS.asarray1i([len(seq) for seq in Xs])
#      77 Xf = layer.ops.flatten(Xs, pad=pad)
# ---> 78 Yf, get_dXf = layer(Xf, is_train)
#      80 def backprop(dYs: ListXd) -> ListXd:
#      81     dYf = layer.ops.flatten(dYs, pad=pad)
#
# File ~/Library/Python/3.9/lib/python/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/Library/Python/3.9/lib/python/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/Library/Python/3.9/lib/python/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/Library/Python/3.9/lib/python/site-packages/thinc/layers/residual.py:41, in forward(model, X, is_train)
#      38     else:
#      39         return d_output + dX
# ---> 41 Y, backprop_layer = model.layers[0](X, is_train)
#      42 if isinstance(X, list):
#      43     return [X[i] + Y[i] for i in range(len(X))], backprop
#
# File ~/Library/Python/3.9/lib/python/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/Library/Python/3.9/lib/python/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/Library/Python/3.9/lib/python/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/Library/Python/3.9/lib/python/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
#     [... skipping similar frames: Model.__call__ at line 291 (1 times)]
#
# File ~/Library/Python/3.9/lib/python/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/Library/Python/3.9/lib/python/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/Library/Python/3.9/lib/python/site-packages/thinc/layers/maxout.py:53, in forward(model, X, is_train)
#      51 W = model.get_param("W")
#      52 W = model.ops.reshape2f(W, nO * nP, nI)
# ---> 53 Y = model.ops.gemm(X, W, trans2=True)
#      54 Y += model.ops.reshape1f(b, nO * nP)
#      55 Z = model.ops.reshape3f(Y, Y.shape[0], nO, nP)
#
# KeyboardInterrupt:

# %% [markdown]
# # Evaluation on the test data

# %% [markdown]
# ## Prepare test data predictions

# %%
def transform_to_iob(nlp_model, data):
    transformed_data = []
    for text, annot in data:
        doc = nlp_model(text)
        # Extract IOB tokens from the SpaCy doc
        iob_tokens = [f"{t.ent_iob_}-{t.ent_type_}" if t.ent_type_ else t.ent_iob_ for t in doc]
        transformed_data.append(iob_tokens)
    return transformed_data

predictions_iob = transform_to_iob(nlp, test_data)

# %%
predictions_iob[:3]
# Out:
# [['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-dating_criteria',
#   'I-dating_criteria'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-inscription',
#   'I-inscription'],
#  ['B-other', 'I-other']]

# %% [markdown]
# ## Prepare the true test data (groundtruth)

# %%
def transform_annotations_to_iob(data, nlp):
    iob_annotations = []

    for text, annot in data:
        doc = nlp.make_doc(text)  # Create a doc from text to ensure correct offsets
        tags = ['O'] * len(doc)  # Initialize tags with 'O'

        entities = annot['entities']
        # Convert character offsets to token offsets
        for start_char, end_char, label in entities:
            start_token, end_token = None, None
            for token_index, token in enumerate(doc):
                # Check if we've found the start token
                if token.idx == start_char:
                    start_token = token_index
                # Check if the current token extends beyond the start of the end_char range
                if token.idx + len(token) == end_char:
                    end_token = token_index
                # If the token encompasses the end character
                if token.idx + len(token) > end_char and end_token is None:
                    end_token = token_index

            if start_token is not None and end_token is not None:
                tags[start_token] = f"B-{label}"
                for i in range(start_token + 1, end_token + 1):
                    tags[i] = f"I-{label}"

        iob_annotations.append(tags)
    return iob_annotations

references_iob = transform_annotations_to_iob(test_data, nlp)

# %% [markdown]
# ## Results evaluation

# %%
# !pip install seqeval

# %%
from seqeval.metrics import classification_report, accuracy_score, f1_score

# Assuming predictions_iob and references_iob are ready
results = classification_report(references_iob, predictions_iob, digits=4)
accuracy = accuracy_score(references_iob, predictions_iob)
f1 = f1_score(references_iob, predictions_iob)

print("Classification Report:\n", results)
print("Accuracy Score:", accuracy)
print("F1 Score:", f1 * 100.0, "%")
# Out:
# Classification Report:
#                        precision    recall  f1-score   support
#
#      dating_criteria     1.0000    1.0000    1.0000        42
#           decoration     0.8000    0.8000    0.8000         5
# epigraphic_shorthand     0.0000    0.0000    0.0000         1
#  execution_technique     0.8000    0.8000    0.8000         5
#          inscription     1.0000    1.0000    1.0000        93
#     inscription_type     0.0000    0.0000    0.0000         1
#             monument     0.0000    0.0000    0.0000         1
#          object_type     1.0000    1.0000    1.0000         6
#                other     0.9762    0.9762    0.9762        42
#   preservation_state     0.0000    0.0000    0.0000         1
#
#            micro avg     0.9845    0.9645    0.9744       197
#            macro avg     0.5576    0.5576    0.5576       197
#         weighted avg     0.9645    0.9645    0.9645       197
#
# Accuracy Score: 0.9915407854984895
# F1 Score: 97.43589743589743 %
# /Users/eboros/Library/Python/3.9/lib/python/site-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Example - how to use it

# %%
text = "мурування апсиди ХІІ ст. г давні ХІ ст. пройми арок галереї закла-."
doc = nlp(text)
print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
# Out:
# Entities [('мурування апсиди', 'object_type')]

# %%
for text, _ in test_data[:5]:
    doc = nlp(text)
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
    print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc if 'inscription' in t.ent_type_])
# Out:
# Entities [('Датування .', 'dating_criteria')]
# Tokens []
# Entities [('Опис .', 'inscription')]
# Tokens [('Опис', 'inscription', 3), ('.', 'inscription', 1)]
# Entities [('Розташування .', 'other')]
# Tokens []
# Entities [('прокреслений', 'execution_technique'), ('чотириконечний хрест з', 'decoration'), ('Датування .', 'dating_criteria')]
# Tokens []
# Entities [('Датування .', 'dating_criteria')]
# Tokens []
